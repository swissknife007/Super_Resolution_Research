# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_image_prefix(image_name):
    return image_name.split('_', 1)[0]
def get_image_width(image_name):
    yo = image_name.split("_")
    return yo[2]
def get_image_height(image_name):
    yo = image_name.split("_")
    return yo[3].split('.',1)[0]
def create_image(image_folder, output_folder, output_type = 'YCbCr',upsampling_factor = 4):
    reconstruct = dict()
    for (dirpath,dirnames,filenames) in os.walk(image_folder):
        print image_folder
        filenames.sort()
        #print(filenames)
        
        for counter,image_filename in enumerate(filenames):
            print(get_image_prefix(image_filename))
            print('\n')
            actual_image_name = get_image_prefix(image_filename)
            if(actual_image_name not in reconstruct):
                reconstruct[actual_image_name] = np.zeros((8,8,3))
            if image_filename.split('.')[-1] == 'bmp' and image_filename[0] != '.':
                if counter % 10 == 0:
                    print "processed:" + str(counter)
                image = misc.imread(os.path.join(image_folder,image_filename),flatten=False, mode = output_type)
                #(width,height,channel_depth)
                w = int(get_image_width(image_filename))
                h = int(get_image_height(image_filename))
                print (w,h)
                print(image.shape)
                print(reconstruct[actual_image_name][14*w:14*w+33,14*h:14*h+33,:].shape)
                reconstruct[actual_image_name][14*w:14*w+33,14*h:14*h+33,:] = image
                #misc.imshow(reconstruct[actual_image_name])
                #img = Image.fromarray(data, 'RGB')
                img = Image.fromarray(reconstruct[actual_image_name], 'RGB')
                img.save('my.png')
                img.show()
                misc.imsave(os.path.join(actual_image_name+'.bmp'),reconstruct[actual_image_name])
    #for key in recstruct:
        #misc.imsave(os.path.join(output_folder,actual_image_name+'.bmp'),reconstruct[actual_image_name])
#create_image('/home/ubuntu/Data/Validation_Subsamples_RGB_4','/home/ubuntu/Data/Reconstructed',output_type ='RGB',upsampling_factor = 4)

# %%
#Create Validation_Subsamples_RGB_4 and Validation_Subsamples_RGB_4_GT folders
Fpreprocessing.create_subimages('/home/ubuntu/Data/Set5',
'/home/ubuntu/Data/Validation_Subsamples_RGB_4',
output_type ='RGB',upsampling_factor = 4)
# Out:
# /home/ubuntu/Data/Set5
# processed:0

# %%
Fpreprocessing.create_subimages('/home/ubuntu/Data/Set14',
'/home/ubuntu/Data/Test_Subsamples_RGB_4',
output_type ='RGB',upsampling_factor = 4)
# Out:
# /home/ubuntu/Data/Set14
# processed:0
# processed:10

# %%
import FSRCNN_Theano2

#load dataset

#load training
data_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')
print "done loading\n\n"
print "data_x: " + str(data_x.shape)
print "data_y: " + str(data_y.shape)
print "valid_x: " + str(valid_x.shape)
print "valid_y: " + str(valid_y.shape)
print "test_x: " + str(test_x.shape)
print "test_y: " + str(test_y.shape)
# Out:
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# done loading
#
#
# data_x: (22092, 3, 8, 8)
# data_y: (22092, 3, 33, 33)
# valid_x: (2488, 3, 8, 8)
# valid_y: (2488, 3, 33, 33)
# test_x: (14851, 3, 8, 8)
# test_y: (14851, 3, 33, 33)

# %%
#Bicubic interp to save computation during training
upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape
# Out:
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
# (22092, 192)
# (22092, 3267)
# (2488, 192)
# (14851, 192)

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
#shared_y = T.cast(shared_y,'int32')

batch_size = 100
n_epochs = 10
lrs = [.001]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
# Out:
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 100)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (100, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 1, 1)
# image_shape...: (100, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 1, 1)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 10, 10)
# image_shape...: (100, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 17)
# epoch 1, minibatch 220/220, validation cost 36178804.000000 mse/pixel: 41728.726562 pnsr: 1.943156
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 1, minibatch 220/220, test cost of best model 37847132.000000 perpixel mse 43652.976562 and test pnsr 1.745544
# epoch 2, minibatch 220/220, validation cost 21374900.000000 mse/pixel: 24653.865234 pnsr: 4.228379
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 2, minibatch 220/220, test cost of best model 21692876.000000 perpixel mse 25020.619141 and test pnsr 4.159567
# epoch 3, minibatch 220/220, validation cost 18213892.000000 mse/pixel: 21007.947266 pnsr: 4.924618
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 3, minibatch 220/220, test cost of best model 18358904.000000 perpixel mse 21175.210938 and test pnsr 4.883519
# epoch 4, minibatch 220/220, validation cost 17041714.000000 mse/pixel: 19655.955078 pnsr: 5.214493
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 4, minibatch 220/220, test cost of best model 17112398.000000 perpixel mse 19737.484375 and test pnsr 5.189079
# epoch 5, minibatch 220/220, validation cost 16521688.000000 mse/pixel: 19056.158203 pnsr: 5.349751
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 5, minibatch 220/220, test cost of best model 16547313.000000 perpixel mse 19085.712891 and test pnsr 5.335227
# epoch 6, minibatch 220/220, validation cost 16229247.000000 mse/pixel: 18718.855469 pnsr: 5.427733
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 6, minibatch 220/220, test cost of best model 16217835.000000 perpixel mse 18705.693359 and test pnsr 5.422748
# epoch 7, minibatch 220/220, validation cost 16053763.000000 mse/pixel: 18516.451172 pnsr: 5.475234
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 7, minibatch 220/220, test cost of best model 16017596.000000 perpixel mse 18474.736328 and test pnsr 5.476834
# epoch 8, minibatch 220/220, validation cost 15933127.000000 mse/pixel: 18377.310547 pnsr: 5.508234
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 8, minibatch 220/220, test cost of best model 15887484.000000 perpixel mse 18324.666016 and test pnsr 5.512352
# epoch 9, minibatch 220/220, validation cost 15837499.000000 mse/pixel: 18267.011719 pnsr: 5.534617
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 9, minibatch 220/220, test cost of best model 15790178.000000 perpixel mse 18212.431641 and test pnsr 5.539149
# epoch 10, minibatch 220/220, validation cost 15783793.000000 mse/pixel: 18205.068359 pnsr: 5.549503
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 10, minibatch 220/220, test cost of best model 15713419.000000 perpixel mse 18123.896484 and test pnsr 5.560410
# Optimization complete.
# Best validation pnsr of 15783793.000000 obtained at iteration 2200, with test cost 15713419.000000 perpixel mse 18123.896484 test pnsr 5.560410
# The training process for function train_FSRCNN ran for 3.55m

# %% [markdown]
# 10 epochs takes 1.4m with batchsize=20
# 10 epochs takes .81m with batchsize=50
# 10 epochs takes 1.3m with batchsize=10
# 10 epochs takes .59m with batchsize=100 cost = 11404075.000000, mse/pixel = 8619.859375, pnsr = 8.786202

# %%
# %autosave 300

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 50
n_epochs = 100
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull')
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=16,dataset='test_lr=5e4_batch_25_modelfull')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull', place=True)
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=16,dataset='test_lr=5e4_batch=25_modelfull',place=True)
# Out:
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 50)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (50, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 1, 1)
# image_shape...: (50, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 1, 1)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 10, 10)
# image_shape...: (50, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 17)
# epoch 1, minibatch 441/441, validation cost 24927618.000000 mse/pixel: 28751.578125 pnsr: 4.191746
#      epoch 1, minibatch 441/441, test cost of best model 24553194.000000 perpixel mse 28319.716797 and test pnsr 4.150471
# epoch 2, minibatch 441/441, validation cost 18283236.000000 mse/pixel: 21087.929688 pnsr: 5.718058
#      epoch 2, minibatch 441/441, test cost of best model 17711042.000000 perpixel mse 20427.962891 and test pnsr 5.599405
# epoch 3, minibatch 441/441, validation cost 15896499.000000 mse/pixel: 18335.060547 pnsr: 6.489047
#      epoch 3, minibatch 441/441, test cost of best model 15462416.000000 perpixel mse 17834.388672 and test pnsr 6.219395
# epoch 4, minibatch 441/441, validation cost 15535830.000000 mse/pixel: 17919.066406 pnsr: 6.651219
#      epoch 4, minibatch 441/441, test cost of best model 15086544.000000 perpixel mse 17400.857422 and test pnsr 6.342658
# epoch 5, minibatch 441/441, validation cost 15269057.000000 mse/pixel: 17611.369141 pnsr: 6.741439
#      epoch 5, minibatch 441/441, test cost of best model 14856904.000000 perpixel mse 17135.992188 and test pnsr 6.413373
# epoch 6, minibatch 441/441, validation cost 15107324.000000 mse/pixel: 17424.826172 pnsr: 6.796399
#      epoch 6, minibatch 441/441, test cost of best model 14691959.000000 perpixel mse 16945.744141 and test pnsr 6.462240
# epoch 7, minibatch 441/441, validation cost 15023600.000000 mse/pixel: 17328.259766 pnsr: 6.825350
#      epoch 7, minibatch 441/441, test cost of best model 14594627.000000 perpixel mse 16833.480469 and test pnsr 6.491108
# epoch 8, minibatch 441/441, validation cost 14968470.000000 mse/pixel: 17264.673828 pnsr: 6.844999
#      epoch 8, minibatch 441/441, test cost of best model 14524738.000000 perpixel mse 16752.871094 and test pnsr 6.511914
# epoch 9, minibatch 441/441, validation cost 14940558.000000 mse/pixel: 17232.478516 pnsr: 6.855652
#      epoch 9, minibatch 441/441, test cost of best model 14496816.000000 perpixel mse 16720.666016 and test pnsr 6.521210
# epoch 10, minibatch 441/441, validation cost 14920451.000000 mse/pixel: 17209.285156 pnsr: 6.862552
#      epoch 10, minibatch 441/441, test cost of best model 14472588.000000 perpixel mse 16692.720703 and test pnsr 6.528609
# epoch 11, minibatch 441/441, validation cost 14901983.000000 mse/pixel: 17187.986328 pnsr: 6.868924
#      epoch 11, minibatch 441/441, test cost of best model 14444149.000000 perpixel mse 16659.919922 and test pnsr 6.537117
# epoch 12, minibatch 441/441, validation cost 14884035.000000 mse/pixel: 17167.283203 pnsr: 6.874869
#      epoch 12, minibatch 441/441, test cost of best model 14416112.000000 perpixel mse 16627.580078 and test pnsr 6.545414
# epoch 13, minibatch 441/441, validation cost 14860440.000000 mse/pixel: 17140.068359 pnsr: 6.882043
#      epoch 13, minibatch 441/441, test cost of best model 14382608.000000 perpixel mse 16588.935547 and test pnsr 6.555191
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a54f042b7335> in <module>()
#      34                              shared_test_x,shared_test_y,
#      35                             n_train_batches, n_valid_batches, n_test_batches,
# ---> 36                              n_epochs, batch_size,learning_rate,upsampling_factor=4)
#      37 reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
#      38 for i in xrange(n_valid_batches):
#
# /mnt/e4040_project_ahj1/FSRCNN_Theano2.pyc in train_FSRCNN(train_set_x, train_set_y, valid_set_x, valid_set_y, test_set_x, test_set_y, n_train_batches, n_valid_batches, n_test_batches, n_epochs, batch_size, lr, upsampling_factor)
#     193     train_nn(train_model, validate_model, test_model,
#     194             n_train_batches, n_valid_batches, n_test_batches, n_epochs,output_len,decay_learning_rate_function,
# --> 195             verbose = False)
#     196
#     197     return validate_model,test_model
#
# /mnt/e4040_project_ahj1/FSRCNN_Layers.pyc in train_nn(train_model, validate_model, test_model, n_train_batches, n_valid_batches, n_test_batches, n_epochs, output_len, decay_learning_rate_function, verbose)
#     369             iter = (epoch - 1) * n_train_batches + minibatch_index
#     370             #cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index,lr)
# --> 371             cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index)
#     372             if (iter % 100 == 0) and verbose:
#     373                 print('training @ iter = ' + str(iter) + "\tcost = " + str(cost_ij) +
#
# /mnt/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 50
n_epochs = 100
lrs = [.01]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 17, 17))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=17,dataset='validate_lr=5e4_batch=25_modelfull')
reconstructed_imgs = np.zeros((14851, 3, 17, 17))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=17,dataset='test_lr=5e4_batch_25_modelfull')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 17, 17))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=17,dataset='validate_lr=5e4_batch=25_modelfull', place=True)
reconstructed_imgs = np.zeros((14851, 3, 17, 17))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=17,dataset='test_lr=5e4_batch=25_modelfull',place=True)
# Out:
#  ****************************** lr = 0.01******************************************
# theano optimizer: fast_compile
# ('batch size', 50)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (50, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 1, 1)
# image_shape...: (50, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 1, 1)
# image_shape...: (50, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 10, 10)
# image_shape...: (50, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 17)
# epoch 1, minibatch 441/441, validation cost 11915695.000000 mse/pixel: 13743.592773 pnsr: 7.800739
#      epoch 1, minibatch 441/441, test cost of best model 11613685.000000 perpixel mse 13395.252930 and test pnsr 7.481399
# epoch 2, minibatch 441/441, validation cost 10539224.000000 mse/pixel: 12155.966797 pnsr: 8.299589
#      epoch 2, minibatch 441/441, test cost of best model 10281694.000000 perpixel mse 11858.932617 and test pnsr 7.998083
# epoch 3, minibatch 441/441, validation cost 10130819.000000 mse/pixel: 11684.912109 pnsr: 8.470465
#      epoch 3, minibatch 441/441, test cost of best model 9844439.000000 perpixel mse 11354.602539 and test pnsr 8.186903
# epoch 4, minibatch 441/441, validation cost 10038572.000000 mse/pixel: 11578.515625 pnsr: 8.507022
#      epoch 4, minibatch 441/441, test cost of best model 9685083.000000 perpixel mse 11170.800781 and test pnsr 8.249634
# epoch 5, minibatch 441/441, validation cost 10006209.000000 mse/pixel: 11541.188477 pnsr: 8.523204
#      epoch 5, minibatch 441/441, test cost of best model 9656013.000000 perpixel mse 11137.271484 and test pnsr 8.264839
# epoch 6, minibatch 441/441, validation cost 9920857.000000 mse/pixel: 11442.740234 pnsr: 8.561133
#      epoch 6, minibatch 441/441, test cost of best model 9594632.000000 perpixel mse 11066.472656 and test pnsr 8.294787
# epoch 7, minibatch 441/441, validation cost 9804516.000000 mse/pixel: 11308.555664 pnsr: 8.611784
#      epoch 7, minibatch 441/441, test cost of best model 9472420.000000 perpixel mse 10925.513672 and test pnsr 8.349670
# epoch 8, minibatch 441/441, validation cost 9896746.000000 mse/pixel: 11414.932617 pnsr: 8.574626
# epoch 9, minibatch 441/441, validation cost 9777024.000000 mse/pixel: 11276.844727 pnsr: 8.624181
#      epoch 9, minibatch 441/441, test cost of best model 9435102.000000 perpixel mse 10882.469727 and test pnsr 8.367106
# epoch 10, minibatch 441/441, validation cost 9905120.000000 mse/pixel: 11424.590820 pnsr: 8.573007
# epoch 11, minibatch 441/441, validation cost 9685410.000000 mse/pixel: 11171.175781 pnsr: 8.661421
#      epoch 11, minibatch 441/441, test cost of best model 9332900.000000 perpixel mse 10764.590820 and test pnsr 8.411484
# epoch 12, minibatch 441/441, validation cost 9751555.000000 mse/pixel: 11247.469727 pnsr: 8.637877
# epoch 13, minibatch 441/441, validation cost 9687452.000000 mse/pixel: 11173.532227 pnsr: 8.662404
# epoch 14, minibatch 441/441, validation cost 9681640.000000 mse/pixel: 11166.830078 pnsr: 8.665362
#      epoch 14, minibatch 441/441, test cost of best model 9343833.000000 perpixel mse 10777.201172 and test pnsr 8.409686
# epoch 15, minibatch 441/441, validation cost 9736374.000000 mse/pixel: 11229.958984 pnsr: 8.638041
# epoch 16, minibatch 441/441, validation cost 9578270.000000 mse/pixel: 11047.601562 pnsr: 8.711463
#      epoch 16, minibatch 441/441, test cost of best model 9247296.000000 perpixel mse 10665.855469 and test pnsr 8.453883
# epoch 17, minibatch 441/441, validation cost 9741545.000000 mse/pixel: 11235.921875 pnsr: 8.640602
# epoch 18, minibatch 441/441, validation cost 9560435.000000 mse/pixel: 11027.029297 pnsr: 8.715004
#      epoch 18, minibatch 441/441, test cost of best model 9219646.000000 perpixel mse 10633.964844 and test pnsr 8.465297
# epoch 19, minibatch 441/441, validation cost 9724005.000000 mse/pixel: 11215.694336 pnsr: 8.646935
# epoch 20, minibatch 441/441, validation cost 9654714.000000 mse/pixel: 11135.773438 pnsr: 8.676730
# epoch 21, minibatch 441/441, validation cost 9683216.000000 mse/pixel: 11168.645508 pnsr: 8.668410
# epoch 22, minibatch 441/441, validation cost 9706974.000000 mse/pixel: 11196.049805 pnsr: 8.655635
# epoch 23, minibatch 441/441, validation cost 9632034.000000 mse/pixel: 11109.613281 pnsr: 8.688738
# epoch 24, minibatch 441/441, validation cost 9569922.000000 mse/pixel: 11037.973633 pnsr: 8.714495
# epoch 25, minibatch 441/441, validation cost 9742532.000000 mse/pixel: 11237.061523 pnsr: 8.641197
# epoch 26, minibatch 441/441, validation cost 9627239.000000 mse/pixel: 11104.082031 pnsr: 8.687438
# epoch 27, minibatch 441/441, validation cost 9583129.000000 mse/pixel: 11053.207031 pnsr: 8.708068
# epoch 28, minibatch 441/441, validation cost 9555865.000000 mse/pixel: 11021.758789 pnsr: 8.720966
#      epoch 28, minibatch 441/441, test cost of best model 9209866.000000 perpixel mse 10622.683594 and test pnsr 8.470162
# epoch 29, minibatch 441/441, validation cost 9654975.000000 mse/pixel: 11136.074219 pnsr: 8.679854
# epoch 30, minibatch 441/441, validation cost 9590575.000000 mse/pixel: 11061.792969 pnsr: 8.707832
# epoch 31, minibatch 441/441, validation cost 9693445.000000 mse/pixel: 11180.444336 pnsr: 8.663048
# epoch 32, minibatch 441/441, validation cost 9681136.000000 mse/pixel: 11166.246094 pnsr: 8.667542
# epoch 33, minibatch 441/441, validation cost 9555842.000000 mse/pixel: 11021.732422 pnsr: 8.720279
#      epoch 33, minibatch 441/441, test cost of best model 9189490.000000 perpixel mse 10599.179688 and test pnsr 8.478563
# epoch 34, minibatch 441/441, validation cost 9622378.000000 mse/pixel: 11098.475586 pnsr: 8.693139
# epoch 35, minibatch 441/441, validation cost 9611488.000000 mse/pixel: 11085.914062 pnsr: 8.696578
# epoch 36, minibatch 441/441, validation cost 9662648.000000 mse/pixel: 11144.923828 pnsr: 8.676816
# epoch 37, minibatch 441/441, validation cost 9697155.000000 mse/pixel: 11184.723633 pnsr: 8.656628
# epoch 38, minibatch 441/441, validation cost 9626721.000000 mse/pixel: 11103.484375 pnsr: 8.691598
# epoch 39, minibatch 441/441, validation cost 9572763.000000 mse/pixel: 11041.250000 pnsr: 8.715509
# epoch 40, minibatch 441/441, validation cost 9569477.000000 mse/pixel: 11037.458984 pnsr: 8.715604
# epoch 41, minibatch 441/441, validation cost 9571381.000000 mse/pixel: 11039.654297 pnsr: 8.713683
# epoch 42, minibatch 441/441, validation cost 9647526.000000 mse/pixel: 11127.480469 pnsr: 8.683899
# epoch 43, minibatch 441/441, validation cost 9684312.000000 mse/pixel: 11169.911133 pnsr: 8.666469
# epoch 44, minibatch 441/441, validation cost 9656816.000000 mse/pixel: 11138.196289 pnsr: 8.677652
# epoch 45, minibatch 441/441, validation cost 9539154.000000 mse/pixel: 11002.486328 pnsr: 8.726935
#      epoch 45, minibatch 441/441, test cost of best model 9199160.000000 perpixel mse 10610.333984 and test pnsr 8.476917
# epoch 46, minibatch 441/441, validation cost 9621024.000000 mse/pixel: 11096.913086 pnsr: 8.690970
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-530b6f93f64b> in <module>()
#      34                              shared_test_x,shared_test_y,
#      35                             n_train_batches, n_valid_batches, n_test_batches,
# ---> 36                              n_epochs, batch_size,learning_rate,upsampling_factor=4)
#      37 reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 17, 17))
#      38 for i in xrange(n_valid_batches):
#
# /mnt/e4040_project_ahj1/FSRCNN_Theano2.pyc in train_FSRCNN(train_set_x, train_set_y, valid_set_x, valid_set_y, test_set_x, test_set_y, n_train_batches, n_valid_batches, n_test_batches, n_epochs, batch_size, lr, upsampling_factor)
#     391     train_nn(train_model, validate_model, test_model,
#     392             n_train_batches, n_valid_batches, n_test_batches, n_epochs,output_len,decay_learning_rate_function,
# --> 393             verbose = False)
#     394
#     395     return validate_model,test_model
#
# /mnt/e4040_project_ahj1/FSRCNN_Layers.pyc in train_nn(train_model, validate_model, test_model, n_train_batches, n_valid_batches, n_test_batches, n_epochs, output_len, decay_learning_rate_function, verbose)
#     369             iter = (epoch - 1) * n_train_batches + minibatch_index
#     370             #cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index,lr)
# --> 371             cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index)
#     372             if (iter % 100 == 0) and verbose:
#     373                 print('training @ iter = ' + str(iter) + "\tcost = " + str(cost_ij) +
#
# /mnt/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 50
n_epochs = 100
lrs = [.01]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 17, 17))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=17,dataset='validate_lr=5e4_batch=25_modelfull')
reconstructed_imgs = np.zeros((14851, 3, 17, 17))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=17,dataset='test_lr=5e4_batch_25_modelfull')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 17, 17))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=17,dataset='validate_lr=5e4_batch=25_modelfull', place=True)
reconstructed_imgs = np.zeros((14851, 3, 17, 17))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=17,dataset='test_lr=5e4_batch=25_modelfull',place=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-530b6f93f64b> in <module>()
#       4 shared_y = theano.shared(np.asarray(data_y,
#       5                                        dtype=theano.config.floatX),
# ----> 6                          borrow=True)
#       7 shared_val_x = theano.shared(np.asarray(up_val_x,
#       8                                        dtype=theano.config.floatX),
#
# /mnt/anaconda2/lib/python2.7/site-packages/theano/compile/sharedvalue.pyc in shared(value, name, strict, allow_downcast, **kwargs)
#     245             try:
#     246                 var = ctor(value, name=name, strict=strict,
# --> 247                            allow_downcast=allow_downcast, **kwargs)
#     248                 utils.add_tag_trace(var)
#     249                 return var
#
# /mnt/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/var.pyc in float32_shared_constructor(value, name, strict, allow_downcast, borrow, broadcastable, target)
#     238         # type.broadcastable is guaranteed to be a tuple, which this next
#     239         # function requires
# --> 240         deviceval = type_support_filter(value, type.broadcastable, False, None)
#     241
#     242     try:
#
# MemoryError: ('Error allocating 288698256 bytes of device memory (out of memory).', "you might consider using 'theano.shared(..., borrow=True)'")
