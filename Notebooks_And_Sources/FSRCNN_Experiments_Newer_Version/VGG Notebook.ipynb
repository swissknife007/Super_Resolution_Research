# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import SRCNN_VGG_Theano
import os
import preprocessing_VGG
from scipy import ndimage,misc
# Out:
# Using gpu device 0: Tesla M2050 (CNMeM is disabled, cuDNN not available)
# /mnt/anaconda2/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
#Create Validation_Subsamples_RGB_4 and Validation_Subsamples_RGB_4_GT folders
#preprocessing.create_subimages('/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Set5',
#'/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Validation_Subsamples_RGB_4',
#output_type ='RGB',upsampling_factor = 4)

#preprocessing.create_subimages('/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Set14',
#'/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Test_Subsamples_RGB_4',
#output_type ='RGB',upsampling_factor = 4)

#preprocessing.create_subimages('/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Training_Full',
#'/home/jon/Documents/Neural_Networks/project/SRCNN_Theano/Data/Training_Subsamples_RGB_4',
#output_type ='RGB',upsampling_factor = 4)

# %%
#load dataset

#load training
data_x = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
print "done loading\n\n"
print "data_x: " + str(data_x.shape)
print "data_y: " + str(data_y.shape)
# Out:
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# done loading
#
#
# data_x: (22092, 3, 8, 8)
# data_y: (22092, 3, 33, 33)

# %%
valid_x = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
print "valid_x: " + str(valid_x.shape)
print "valid_y: " + str(valid_y.shape)
# Out:
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# valid_x: (2488, 3, 8, 8)
# valid_y: (2488, 3, 33, 33)

# %%
test_x = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = SRCNN_VGG_Theano.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')
print "test_x: " + str(test_x.shape)
print "test_y: " + str(test_y.shape)
# Out:
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# test_x: (14851, 3, 8, 8)
# test_y: (14851, 3, 33, 33)

# %%
#Bicubic interp to save computation during training
upsampled_x = preprocessing_VGG.upsample(data_x) #33,33,3 input images expected
up_val_x = preprocessing_VGG.upsample(valid_x) #33,33,3 input images expected
up_test_x = preprocessing_VGG.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test
upsampled_x = upsampled_x.reshape((22092,33*33*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,33*33*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,33*33*3))
test_y = test_y.reshape((14851,33*33*3))

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape
# Out:
# (22092, 3267)
# (22092, 3267)
# (2488, 3267)
# (14851, 3267)

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)

# %%
batch_size = 128
n_epochs = 5
#lrs = [.1,.07,.05,.03,.007,.005,.002,.0009,.0007,.0004,.0001]
lrs = [.0001]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    train_model,val_model,test_model = SRCNN_VGG_Theano.train_SRCNN_VGG(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
# Out:
#  ****************************** lr = 0.0001******************************************
# theano optimizer: fast_compile
# ... building the vgg model for low resolution input
# ('im_dims=', array([21, 21]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# ... building the vgg model for high resolution input
# ('im_dims=', array([33, 33]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# epoch 1, minibatch 172/172, validation cost 13132918.000000 mse/pixel: 1026.009163 pnsr: 18.531364
#      epoch 1, minibatch 172/172, test cost of best model 12822550.000000 perpixel mse 1001.761650 and test pnsr 18.708705
# epoch 2, minibatch 172/172, validation cost 12467094.000000 mse/pixel: 973.991745 pnsr: 18.529727
#      epoch 2, minibatch 172/172, test cost of best model 12933553.000000 perpixel mse 1010.433693 and test pnsr 18.421222
# epoch 3, minibatch 172/172, validation cost 13428615.000000 mse/pixel: 1049.110453 pnsr: 18.446526
# epoch 4, minibatch 172/172, validation cost 12905171.000000 mse/pixel: 1008.216458 pnsr: 18.542157
# epoch 5, minibatch 172/172, validation cost 13283683.000000 mse/pixel: 1037.787644 pnsr: 18.455570
# Optimization complete.
# Best validation pnsr of 12467094.000000 obtained at iteration 344, with test cost 12933553.000000 perpixel mse 1010.433693 test pnsr 18.421222
# The training process for function train_SRCNN_VGG ran for 12.38m

# %%
reconstructed_imgs = np.zeros((14851, 3, 21, 21))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

SRCNN_VGG_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=21,dataset='test')

# %%
display_img_path = '/home/ubuntu/e4040_project_ahj1/recon_imgs_VGG_test/baboon.bmp'

# %%
cmd = os.environ.get('SCIPY_PIL_IMAGE_VIEWER', 'see')

# %%
from PIL import Image
imgx = (Image.open(display_img_path))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(imgx)

# %%
#with input to VGG just the center pixels 21x21 

batch_size = 100
n_epochs = 5
#lrs = [.1,.07,.05,.03,.007,.005,.002,.0009,.0007,.0004,.0001]
lrs = [.0001]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    train_model,val_model,test_model = SRCNN_VGG_Theano.train_SRCNN_VGG(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
# Out:
#  ****************************** lr = 0.0001******************************************
# theano optimizer: fast_compile
# ... building the vgg model for low resolution input
# ('im_dims=', array([21, 21]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# ... building the vgg model for high resolution input
# ('im_dims=', array([21, 21]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# epoch 1, minibatch 220/220, validation cost 7271066.000000 mse/pixel: 568.052021 pnsr: 21.124129
#      epoch 1, minibatch 220/220, test cost of best model 7346589.500000 perpixel mse 573.952302 and test pnsr 21.264349
# epoch 2, minibatch 220/220, validation cost 8234662.500000 mse/pixel: 643.333043 pnsr: 20.711685
# epoch 3, minibatch 220/220, validation cost 7409985.500000 mse/pixel: 578.905114 pnsr: 21.010435
# epoch 4, minibatch 220/220, validation cost 7237121.500000 mse/pixel: 565.400066 pnsr: 21.119316
#      epoch 4, minibatch 220/220, test cost of best model 7139849.500000 perpixel mse 557.800748 and test pnsr 21.379754
# epoch 5, minibatch 220/220, validation cost 7088469.500000 mse/pixel: 553.786672 pnsr: 21.138454
#      epoch 5, minibatch 220/220, test cost of best model 6931728.000000 perpixel mse 541.541271 and test pnsr 21.381645
# Optimization complete.
# Best validation pnsr of 7088469.500000 obtained at iteration 1100, with test cost 6931728.000000 perpixel mse 541.541271 test pnsr 21.381645
# The training process for function train_SRCNN_VGG ran for 21.42m

# %%
from PIL import Image
imgx = (Image.open(display_img_path))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(imgx)

# %%
#with input to VGG just the center pixels 21x21 

batch_size = 100
n_epochs = 20
#lrs = [.1,.07,.05,.03,.007,.005,.002,.0009,.0007,.0004,.0001]
lrs = [.0001]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    train_model,val_model,test_model = SRCNN_VGG_Theano.train_SRCNN_VGG(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
# Out:
#  ****************************** lr = 0.0001******************************************
# theano optimizer: fast_compile
# ... building the vgg model for low resolution input
# ('im_dims=', array([21, 21]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# ... building the vgg model for high resolution input
# ('im_dims=', array([21, 21]))
# ('Loading weights for Layer: ', 1)
# ('Weights loaded with dims: ', (64, 3, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 2)
# ('Weights loaded with dims: ', (64, 64, 3, 3), 'and', (64,))
# ('Loading weights for Layer: ', 3)
# ('Weights loaded with dims: ', (128, 64, 3, 3), 'and', (128,))
# ('Loading weights for Layer: ', 4)
# ('Weights loaded with dims: ', (128, 128, 3, 3), 'and', (128,))
# epoch 1, minibatch 220/220, validation cost 7086762.500000 mse/pixel: 553.653374 pnsr: 21.147813
#      epoch 1, minibatch 220/220, test cost of best model 7145390.000000 perpixel mse 558.233589 and test pnsr 21.266023
# epoch 2, minibatch 220/220, validation cost 7193084.000000 mse/pixel: 561.959741 pnsr: 21.149721
# epoch 3, minibatch 220/220, validation cost 7043836.000000 mse/pixel: 550.299677 pnsr: 21.188304
#      epoch 3, minibatch 220/220, test cost of best model 6935045.000000 perpixel mse 541.800386 and test pnsr 21.390048
# epoch 4, minibatch 220/220, validation cost 7132174.500000 mse/pixel: 557.201155 pnsr: 21.177814
# epoch 5, minibatch 220/220, validation cost 7120545.500000 mse/pixel: 556.292609 pnsr: 21.199477
# epoch 6, minibatch 220/220, validation cost 6917830.500000 mse/pixel: 540.455555 pnsr: 21.291472
#      epoch 6, minibatch 220/220, test cost of best model 7029255.500000 perpixel mse 549.160535 and test pnsr 21.414482
# epoch 7, minibatch 220/220, validation cost 7191891.500000 mse/pixel: 561.866517 pnsr: 21.184883
# epoch 8, minibatch 220/220, validation cost 7102014.500000 mse/pixel: 554.844863 pnsr: 21.211201
# epoch 9, minibatch 220/220, validation cost 6725788.000000 mse/pixel: 525.452173 pnsr: 21.344502
#      epoch 9, minibatch 220/220, test cost of best model 6888097.500000 perpixel mse 538.132653 and test pnsr 21.404243
# epoch 10, minibatch 220/220, validation cost 7072039.500000 mse/pixel: 552.503069 pnsr: 21.240885
# epoch 11, minibatch 220/220, validation cost 7162441.500000 mse/pixel: 559.565734 pnsr: 21.164190
# epoch 12, minibatch 220/220, validation cost 7202228.000000 mse/pixel: 562.674104 pnsr: 21.159307
# epoch 13, minibatch 220/220, validation cost 7217070.500000 mse/pixel: 563.833683 pnsr: 21.168210
# epoch 14, minibatch 220/220, validation cost 6684405.500000 mse/pixel: 522.219180 pnsr: 21.365824
#      epoch 14, minibatch 220/220, test cost of best model 6880657.500000 perpixel mse 537.551376 and test pnsr 21.411793
# epoch 15, minibatch 220/220, validation cost 7133610.000000 mse/pixel: 557.313299 pnsr: 21.170019
# epoch 16, minibatch 220/220, validation cost 7184406.500000 mse/pixel: 561.281759 pnsr: 21.178974
# epoch 17, minibatch 220/220, validation cost 7165931.500000 mse/pixel: 559.838399 pnsr: 21.174862
# epoch 18, minibatch 220/220, validation cost 6702462.000000 mse/pixel: 523.629817 pnsr: 21.294560
# epoch 19, minibatch 220/220, validation cost 7546601.500000 mse/pixel: 589.578179 pnsr: 21.031024
# epoch 20, minibatch 220/220, validation cost 7233812.000000 mse/pixel: 565.141544 pnsr: 21.174868
# Optimization complete.
# Best validation pnsr of 6684405.500000 obtained at iteration 3080, with test cost 6880657.500000 perpixel mse 537.551376 test pnsr 21.411793
# The training process for function train_SRCNN_VGG ran for 81.42m
