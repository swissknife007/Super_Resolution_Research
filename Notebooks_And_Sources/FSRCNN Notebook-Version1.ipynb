# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image
# Out:
# Using gpu device 0: Tesla M2050 (CNMeM is disabled, cuDNN not available)
# /mnt/anaconda2/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
def get_image_prefix(image_name):
    return image_name.split('_', 1)[0]
def get_image_width(image_name):
    yo = image_name.split("_")
    return yo[2]
def get_image_height(image_name):
    yo = image_name.split("_")
    return yo[3].split('.',1)[0]
def create_image(image_folder, output_folder, output_type = 'YCbCr',upsampling_factor = 4):
    reconstruct = dict()
    for (dirpath,dirnames,filenames) in os.walk(image_folder):
        print image_folder
        filenames.sort()
        #print(filenames)
        
        for counter,image_filename in enumerate(filenames):
            print(get_image_prefix(image_filename))
            print('\n')
            actual_image_name = get_image_prefix(image_filename)
            if(actual_image_name not in reconstruct):
                reconstruct[actual_image_name] = np.zeros((8,8,3))
            if image_filename.split('.')[-1] == 'bmp' and image_filename[0] != '.':
                if counter % 10 == 0:
                    print "processed:" + str(counter)
                image = misc.imread(os.path.join(image_folder,image_filename),flatten=False, mode = output_type)
                #(width,height,channel_depth)
                w = int(get_image_width(image_filename))
                h = int(get_image_height(image_filename))
                print (w,h)
                print(image.shape)
                print(reconstruct[actual_image_name][14*w:14*w+33,14*h:14*h+33,:].shape)
                reconstruct[actual_image_name][14*w:14*w+33,14*h:14*h+33,:] = image
                #misc.imshow(reconstruct[actual_image_name])
                #img = Image.fromarray(data, 'RGB')
                img = Image.fromarray(reconstruct[actual_image_name], 'RGB')
                img.save('my.png')
                img.show()
                misc.imsave(os.path.join(actual_image_name+'.bmp'),reconstruct[actual_image_name])
    #for key in recstruct:
        #misc.imsave(os.path.join(output_folder,actual_image_name+'.bmp'),reconstruct[actual_image_name])
#create_image('/home/ubuntu/Data/Validation_Subsamples_RGB_4','/home/ubuntu/Data/Reconstructed',output_type ='RGB',upsampling_factor = 4)

# %%
#Create Validation_Subsamples_RGB_4 and Validation_Subsamples_RGB_4_GT folders
Fpreprocessing.create_subimages('/home/ubuntu/Data/Set5',
'/home/ubuntu/Data/Validation_Subsamples_RGB_4',
output_type ='RGB',upsampling_factor = 4)
# Out:
# /home/ubuntu/Data/Set5
# processed:0

# %%
Fpreprocessing.create_subimages('/home/ubuntu/Data/Set14',
'/home/ubuntu/Data/Test_Subsamples_RGB_4',
output_type ='RGB',upsampling_factor = 4)
# Out:
# /home/ubuntu/Data/Set14
# processed:0
# processed:10

# %%
import FSRCNN_Theano2

#load dataset

#load training
data_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')
print "done loading\n\n"
print "data_x: " + str(data_x.shape)
print "data_y: " + str(data_y.shape)
print "valid_x: " + str(valid_x.shape)
print "valid_y: " + str(valid_y.shape)
print "test_x: " + str(test_x.shape)
print "test_y: " + str(test_y.shape)
# Out:
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# done loading
#
#
# data_x: (22092, 3, 8, 8)
# data_y: (22092, 3, 33, 33)
# valid_x: (2488, 3, 8, 8)
# valid_y: (2488, 3, 33, 33)
# test_x: (14851, 3, 8, 8)
# test_y: (14851, 3, 33, 33)

# %%
#Bicubic interp to save computation during training
upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape
# Out:
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
# (22092, 192)
# (22092, 3267)
# (2488, 192)
# (14851, 192)

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
#shared_y = T.cast(shared_y,'int32')

batch_size = 100
n_epochs = 10
lrs = [.001]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
# Out:
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 100)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (100, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 1, 1)
# image_shape...: (100, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 1, 1)
# image_shape...: (100, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 10, 10)
# image_shape...: (100, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 17)
# epoch 1, minibatch 220/220, validation cost 36178804.000000 mse/pixel: 41728.726562 pnsr: 1.943156
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 1, minibatch 220/220, test cost of best model 37847132.000000 perpixel mse 43652.976562 and test pnsr 1.745544
# epoch 2, minibatch 220/220, validation cost 21374900.000000 mse/pixel: 24653.865234 pnsr: 4.228379
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 2, minibatch 220/220, test cost of best model 21692876.000000 perpixel mse 25020.619141 and test pnsr 4.159567
# epoch 3, minibatch 220/220, validation cost 18213892.000000 mse/pixel: 21007.947266 pnsr: 4.924618
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 3, minibatch 220/220, test cost of best model 18358904.000000 perpixel mse 21175.210938 and test pnsr 4.883519
# epoch 4, minibatch 220/220, validation cost 17041714.000000 mse/pixel: 19655.955078 pnsr: 5.214493
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 4, minibatch 220/220, test cost of best model 17112398.000000 perpixel mse 19737.484375 and test pnsr 5.189079
# epoch 5, minibatch 220/220, validation cost 16521688.000000 mse/pixel: 19056.158203 pnsr: 5.349751
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 5, minibatch 220/220, test cost of best model 16547313.000000 perpixel mse 19085.712891 and test pnsr 5.335227
# epoch 6, minibatch 220/220, validation cost 16229247.000000 mse/pixel: 18718.855469 pnsr: 5.427733
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 6, minibatch 220/220, test cost of best model 16217835.000000 perpixel mse 18705.693359 and test pnsr 5.422748
# epoch 7, minibatch 220/220, validation cost 16053763.000000 mse/pixel: 18516.451172 pnsr: 5.475234
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 7, minibatch 220/220, test cost of best model 16017596.000000 perpixel mse 18474.736328 and test pnsr 5.476834
# epoch 8, minibatch 220/220, validation cost 15933127.000000 mse/pixel: 18377.310547 pnsr: 5.508234
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 8, minibatch 220/220, test cost of best model 15887484.000000 perpixel mse 18324.666016 and test pnsr 5.512352
# epoch 9, minibatch 220/220, validation cost 15837499.000000 mse/pixel: 18267.011719 pnsr: 5.534617
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 9, minibatch 220/220, test cost of best model 15790178.000000 perpixel mse 18212.431641 and test pnsr 5.539149
# epoch 10, minibatch 220/220, validation cost 15783793.000000 mse/pixel: 18205.068359 pnsr: 5.549503
# 136
#
#
# <type 'numpy.ndarray'>
# (3, 17, 17)
#      epoch 10, minibatch 220/220, test cost of best model 15713419.000000 perpixel mse 18123.896484 and test pnsr 5.560410
# Optimization complete.
# Best validation pnsr of 15783793.000000 obtained at iteration 2200, with test cost 15713419.000000 perpixel mse 18123.896484 test pnsr 5.560410
# The training process for function train_FSRCNN ran for 3.55m

# %% [markdown]
# 10 epochs takes 1.4m with batchsize=20
# 10 epochs takes .81m with batchsize=50
# 10 epochs takes 1.3m with batchsize=10
# 10 epochs takes .59m with batchsize=100 cost = 11404075.000000, mse/pixel = 8619.859375, pnsr = 8.786202

# %%
# %autosave 300

# %%
shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 50
n_epochs = 100
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull')
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=16,dataset='test_lr=5e4_batch_25_modelfull')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull', place=True)
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=16,dataset='test_lr=5e4_batch=25_modelfull',place=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a54f042b7335> in <module>()
# ----> 1 shared_x = theano.shared(np.asarray(upsampled_x,
#       2                                        dtype=theano.config.floatX),
#       3                          borrow=True)
#       4 shared_y = theano.shared(np.asarray(data_y,
#       5                                        dtype=theano.config.floatX),
#
# NameError: name 'theano' is not defined

# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image

data_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')

upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))


shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 25
n_epochs = 100
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 23, 23))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=23,dataset='validate_lr=5e4_batch=25_modelfull')
reconstructed_imgs = np.zeros((14851, 3, 23, 23))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=23,dataset='test_lr=5e4_batch_25_modelfull')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 23, 23))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4/',patch_dim=23,dataset='validate_lr=5e4_batch=25_modelfull', place=True)
reconstructed_imgs = np.zeros((14851, 3, 23, 23))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4/',patch_dim=23,dataset='test_lr=5e4_batch=25_modelfull',place=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
#
#
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 25)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (25, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (3, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 3, 9, 9)
# image_shape...: (25, 3, 23, 23)
# input shape....: Shape.0
# Shape.0
# Shape.0
# ('output len...', 23)
# epoch 1, minibatch 883/883, validation cost 285260160.000000 mse/pixel: 285260160.000000 pnsr: -20.054995
#      epoch 1, minibatch 883/883, test cost of best model 161211280.000000 perpixel mse 161211280.000000 and test pnsr -14.624934
# epoch 2, minibatch 883/883, validation cost 171919952.000000 mse/pixel: 171919952.000000 pnsr: -15.619527
#      epoch 2, minibatch 883/883, test cost of best model 92148488.000000 perpixel mse 92148488.000000 and test pnsr -9.301254
# epoch 3, minibatch 883/883, validation cost 117266280.000000 mse/pixel: 117266280.000000 pnsr: -12.167720
#      epoch 3, minibatch 883/883, test cost of best model 61576740.000000 perpixel mse 61576740.000000 and test pnsr -5.942114
# epoch 4, minibatch 883/883, validation cost 82758504.000000 mse/pixel: 82758504.000000 pnsr: -9.112476
#      epoch 4, minibatch 883/883, test cost of best model 43622104.000000 perpixel mse 43622104.000000 and test pnsr -3.559765
# epoch 5, minibatch 883/883, validation cost 58928628.000000 mse/pixel: 58928628.000000 pnsr: -7.104000
#      epoch 5, minibatch 883/883, test cost of best model 31527106.000000 perpixel mse 31527106.000000 and test pnsr -1.674268
# epoch 6, minibatch 883/883, validation cost 42456492.000000 mse/pixel: 42456492.000000 pnsr: -5.333908
#      epoch 6, minibatch 883/883, test cost of best model 22156008.000000 perpixel mse 22156008.000000 and test pnsr -0.181188
# epoch 7, minibatch 883/883, validation cost 31515424.000000 mse/pixel: 31515424.000000 pnsr: -3.787148
#      epoch 7, minibatch 883/883, test cost of best model 16066526.000000 perpixel mse 16066526.000000 and test pnsr 0.710314
# epoch 8, minibatch 883/883, validation cost 23900948.000000 mse/pixel: 23900948.000000 pnsr: -2.731263
#      epoch 8, minibatch 883/883, test cost of best model 11667794.000000 perpixel mse 11667794.000000 and test pnsr 1.663881
# epoch 9, minibatch 883/883, validation cost 18670608.000000 mse/pixel: 18670608.000000 pnsr: -1.835852
#      epoch 9, minibatch 883/883, test cost of best model 8707634.000000 perpixel mse 8707634.000000 and test pnsr 2.245818
# epoch 10, minibatch 883/883, validation cost 14706749.000000 mse/pixel: 14706749.000000 pnsr: -0.683192
#      epoch 10, minibatch 883/883, test cost of best model 6480169.500000 perpixel mse 6480169.500000 and test pnsr 2.927427
# epoch 11, minibatch 883/883, validation cost 12286009.000000 mse/pixel: 12286009.000000 pnsr: -0.007472
#      epoch 11, minibatch 883/883, test cost of best model 4945738.000000 perpixel mse 4945738.000000 and test pnsr 3.339512
# epoch 12, minibatch 883/883, validation cost 9982056.000000 mse/pixel: 9982056.000000 pnsr: 0.837709
#      epoch 12, minibatch 883/883, test cost of best model 4157913.750000 perpixel mse 4157913.750000 and test pnsr 3.698313
# epoch 13, minibatch 883/883, validation cost 8369488.000000 mse/pixel: 8369488.000000 pnsr: 1.472061
#      epoch 13, minibatch 883/883, test cost of best model 3651117.750000 perpixel mse 3651117.750000 and test pnsr 3.965127
# epoch 14, minibatch 883/883, validation cost 7017548.500000 mse/pixel: 7017548.500000 pnsr: 1.930879
#      epoch 14, minibatch 883/883, test cost of best model 3155720.250000 perpixel mse 3155720.250000 and test pnsr 4.213016
# epoch 15, minibatch 883/883, validation cost 6063775.000000 mse/pixel: 6063775.000000 pnsr: 2.308450
#      epoch 15, minibatch 883/883, test cost of best model 2835402.500000 perpixel mse 2835402.500000 and test pnsr 4.331351
# epoch 16, minibatch 883/883, validation cost 5569108.000000 mse/pixel: 5569108.000000 pnsr: 2.596732
#      epoch 16, minibatch 883/883, test cost of best model 2603385.000000 perpixel mse 2603385.000000 and test pnsr 4.428552
# epoch 17, minibatch 883/883, validation cost 5310511.000000 mse/pixel: 5310511.000000 pnsr: 2.718552
#      epoch 17, minibatch 883/883, test cost of best model 2502042.000000 perpixel mse 2502042.000000 and test pnsr 4.477579
# epoch 18, minibatch 883/883, validation cost 5112985.500000 mse/pixel: 5112985.500000 pnsr: 2.766753
#      epoch 18, minibatch 883/883, test cost of best model 2422271.250000 perpixel mse 2422271.250000 and test pnsr 4.535476
# epoch 19, minibatch 883/883, validation cost 5105813.500000 mse/pixel: 5105813.500000 pnsr: 2.834761
#      epoch 19, minibatch 883/883, test cost of best model 2391377.500000 perpixel mse 2391377.500000 and test pnsr 4.573329
# epoch 20, minibatch 883/883, validation cost 5049833.000000 mse/pixel: 5049833.000000 pnsr: 2.886323
#      epoch 20, minibatch 883/883, test cost of best model 2382018.000000 perpixel mse 2382018.000000 and test pnsr 4.613848
# epoch 21, minibatch 883/883, validation cost 5046500.000000 mse/pixel: 5046500.000000 pnsr: 2.927282
#      epoch 21, minibatch 883/883, test cost of best model 2379945.750000 perpixel mse 2379945.750000 and test pnsr 4.643256
# epoch 22, minibatch 883/883, validation cost 5049122.000000 mse/pixel: 5049122.000000 pnsr: 2.940887
# epoch 23, minibatch 883/883, validation cost 5049032.500000 mse/pixel: 5049032.500000 pnsr: 2.964840
# epoch 24, minibatch 883/883, validation cost 5048945.000000 mse/pixel: 5048945.000000 pnsr: 2.988758
# epoch 25, minibatch 883/883, validation cost 5048857.500000 mse/pixel: 5048857.500000 pnsr: 3.012630
# epoch 26, minibatch 883/883, validation cost 5048771.000000 mse/pixel: 5048771.000000 pnsr: 3.036449
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-68ee41a94428> in <module>()
#      71                              shared_test_x,shared_test_y,
#      72                             n_train_batches, n_valid_batches, n_test_batches,
# ---> 73                              n_epochs, batch_size,learning_rate,upsampling_factor=4)
#      74 reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 23, 23))
#      75 for i in xrange(n_valid_batches):
#
# /home/ubuntu/e4040_project_ahj1/FSRCNN_Experiments_Newer_Version/FSRCNN_Theano2.py in train_FSRCNN(train_set_x, train_set_y, valid_set_x, valid_set_y, test_set_x, test_set_y, n_train_batches, n_valid_batches, n_test_batches, n_epochs, batch_size, lr, upsampling_factor)
#     394     train_nn(train_model, validate_model, test_model,
#     395             n_train_batches, n_valid_batches, n_test_batches, n_epochs,output_len,decay_learning_rate_function,
# --> 396             verbose = False)
#     397
#     398     return validate_model,test_model
#
# /home/ubuntu/e4040_project_ahj1/FSRCNN_Experiments_Newer_Version/FSRCNN_Layers.pyc in train_nn(train_model, validate_model, test_model, n_train_batches, n_valid_batches, n_test_batches, n_epochs, output_len, decay_learning_rate_function, verbose)
#     425             iter = (epoch - 1) * n_train_batches + minibatch_index
#     426             #cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index,lr)
# --> 427             cost_ij,mse_ij,pnsr_ij = train_model(minibatch_index)
#     428             if (iter % 100 == 0) and verbose:
#     429                 print('training @ iter = ' + str(iter) + "\tcost = " + str(cost_ij) +
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image

data_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano2.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')

upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))


shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 25
n_epochs = 20
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano2.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 23, 23))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=23,dataset='validate_lr=5e4_batch=25_modelfull_SKIP')
reconstructed_imgs = np.zeros((14851, 3, 23, 23))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=23,dataset='test_lr=5e4_batch_25_modelfull_SKIP')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 23, 23))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=23,dataset='validate_lr=5e4_batch=25_modelfull_SKIP', place=True)
reconstructed_imgs = np.zeros((14851, 3, 23, 23))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano2.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=23,dataset='test_lr=5e4_batch=25_modelfull_SKIP',place=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
#
#
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 25)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (25, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (3, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 3, 9, 9)
# image_shape...: (25, 3, 23, 23)
# input shape....: Shape.0
# Shape.0
# Shape.0
# ('output len...', 23)
# epoch 1, minibatch 883/883, validation cost 144314304.000000 mse/pixel: 144314304.000000 pnsr: -27.168869
#      epoch 1, minibatch 883/883, test cost of best model 188026800.000000 perpixel mse 188026800.000000 and test pnsr -24.588848
# epoch 2, minibatch 883/883, validation cost 61815416.000000 mse/pixel: 61815416.000000 pnsr: -19.524706
#      epoch 2, minibatch 883/883, test cost of best model 100944280.000000 perpixel mse 100944280.000000 and test pnsr -17.436357
# epoch 3, minibatch 883/883, validation cost 39492240.000000 mse/pixel: 39492240.000000 pnsr: -14.811828
#      epoch 3, minibatch 883/883, test cost of best model 61794988.000000 perpixel mse 61794988.000000 and test pnsr -12.231893
# epoch 4, minibatch 883/883, validation cost 27914090.000000 mse/pixel: 27914090.000000 pnsr: -10.363353
#      epoch 4, minibatch 883/883, test cost of best model 41640468.000000 perpixel mse 41640468.000000 and test pnsr -8.753757
# epoch 5, minibatch 883/883, validation cost 21824760.000000 mse/pixel: 21824760.000000 pnsr: -8.214340
#      epoch 5, minibatch 883/883, test cost of best model 27933190.000000 perpixel mse 27933190.000000 and test pnsr -5.808549
# epoch 6, minibatch 883/883, validation cost 15940768.000000 mse/pixel: 15940768.000000 pnsr: -6.843163
#      epoch 6, minibatch 883/883, test cost of best model 18937810.000000 perpixel mse 18937810.000000 and test pnsr -3.304598
# epoch 7, minibatch 883/883, validation cost 11065756.000000 mse/pixel: 11065756.000000 pnsr: -5.068456
#      epoch 7, minibatch 883/883, test cost of best model 12990904.000000 perpixel mse 12990904.000000 and test pnsr -1.463262
# epoch 8, minibatch 883/883, validation cost 7230856.500000 mse/pixel: 7230856.500000 pnsr: -3.540953
#      epoch 8, minibatch 883/883, test cost of best model 8951465.000000 perpixel mse 8951465.000000 and test pnsr 0.240970
# epoch 9, minibatch 883/883, validation cost 4790291.500000 mse/pixel: 4790291.500000 pnsr: -1.900970
#      epoch 9, minibatch 883/883, test cost of best model 6337519.000000 perpixel mse 6337519.000000 and test pnsr 1.338347
# epoch 10, minibatch 883/883, validation cost 3437461.000000 mse/pixel: 3437461.000000 pnsr: -0.154587
#      epoch 10, minibatch 883/883, test cost of best model 4681093.000000 perpixel mse 4681093.000000 and test pnsr 2.040632
# epoch 11, minibatch 883/883, validation cost 2508402.250000 mse/pixel: 2508402.250000 pnsr: 0.781490
#      epoch 11, minibatch 883/883, test cost of best model 3446449.250000 perpixel mse 3446449.250000 and test pnsr 2.741612
# epoch 12, minibatch 883/883, validation cost 1954576.125000 mse/pixel: 1954576.125000 pnsr: 1.460915
#      epoch 12, minibatch 883/883, test cost of best model 2738518.000000 perpixel mse 2738518.000000 and test pnsr 3.176795
# epoch 13, minibatch 883/883, validation cost 1577559.250000 mse/pixel: 1577559.250000 pnsr: 1.850404
#      epoch 13, minibatch 883/883, test cost of best model 2252789.000000 perpixel mse 2252789.000000 and test pnsr 3.543210
# epoch 14, minibatch 883/883, validation cost 1363403.500000 mse/pixel: 1363403.500000 pnsr: 2.375241
#      epoch 14, minibatch 883/883, test cost of best model 1961106.375000 perpixel mse 1961106.375000 and test pnsr 3.916305
# epoch 15, minibatch 883/883, validation cost 1221838.500000 mse/pixel: 1221838.500000 pnsr: 2.815372
#      epoch 15, minibatch 883/883, test cost of best model 1737386.875000 perpixel mse 1737386.875000 and test pnsr 4.226203
# epoch 16, minibatch 883/883, validation cost 1178948.750000 mse/pixel: 1178948.750000 pnsr: 3.147901
#      epoch 16, minibatch 883/883, test cost of best model 1613413.500000 perpixel mse 1613413.500000 and test pnsr 4.392065
# epoch 17, minibatch 883/883, validation cost 1191813.625000 mse/pixel: 1191813.625000 pnsr: 3.278105
# epoch 18, minibatch 883/883, validation cost 1214512.750000 mse/pixel: 1214512.750000 pnsr: 3.388261
# epoch 19, minibatch 883/883, validation cost 1217736.625000 mse/pixel: 1217736.625000 pnsr: 3.440480
# epoch 20, minibatch 883/883, validation cost 1205451.750000 mse/pixel: 1205451.750000 pnsr: 3.556731
# Optimization complete.
# Best validation pnsr of 1178948.750000 obtained at iteration 14128, with test cost 1613413.500000 perpixel mse 1613413.500000 test pnsr 4.392065
# The training process for function train_FSRCNN ran for 17.04m
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')

# %% [markdown]
# SKIP CONNECTIONS

# %% [markdown]
# DIFFERENT STYLE OF DECONVOLUTION

# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image
import FSRCNN_Theano3

data_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')

upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))


shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 25
n_epochs = 50
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano3.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv')
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch_25_modelfull_SKIP_BasicDeconv')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIPBasicDeconv', place=True)
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv',place=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
#
#
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 25)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (25, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 9, 9)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 16)
# epoch 1, minibatch 883/883, validation cost 44946596.000000 mse/pixel: 44946596.000000 pnsr: -27.638960
#      epoch 1, minibatch 883/883, test cost of best model 48646548.000000 perpixel mse 48646540.000000 and test pnsr -28.061783
# epoch 2, minibatch 883/883, validation cost 23886794.000000 mse/pixel: 23886792.000000 pnsr: -24.865358
#      epoch 2, minibatch 883/883, test cost of best model 25021770.000000 perpixel mse 25021770.000000 and test pnsr -25.113382
# epoch 3, minibatch 883/883, validation cost 14308295.000000 mse/pixel: 14308294.000000 pnsr: -22.606497
#      epoch 3, minibatch 883/883, test cost of best model 14774860.000000 perpixel mse 14774860.000000 and test pnsr -22.806450
# epoch 4, minibatch 883/883, validation cost 9629064.000000 mse/pixel: 9629064.000000 pnsr: -20.873335
#      epoch 4, minibatch 883/883, test cost of best model 10043405.000000 perpixel mse 10043404.000000 and test pnsr -21.158127
# epoch 5, minibatch 883/883, validation cost 6379437.500000 mse/pixel: 6379436.500000 pnsr: -19.071339
#      epoch 5, minibatch 883/883, test cost of best model 6515098.500000 perpixel mse 6515097.500000 and test pnsr -19.321257
# epoch 6, minibatch 883/883, validation cost 3890176.000000 mse/pixel: 3890175.750000 pnsr: -16.893625
#      epoch 6, minibatch 883/883, test cost of best model 3838577.000000 perpixel mse 3838577.000000 and test pnsr -17.051584
# epoch 7, minibatch 883/883, validation cost 2377283.000000 mse/pixel: 2377282.500000 pnsr: -14.717957
#      epoch 7, minibatch 883/883, test cost of best model 2351448.750000 perpixel mse 2351448.750000 and test pnsr -14.906960
# epoch 8, minibatch 883/883, validation cost 1418837.625000 mse/pixel: 1418837.375000 pnsr: -12.430984
#      epoch 8, minibatch 883/883, test cost of best model 1407464.000000 perpixel mse 1407463.875000 and test pnsr -12.648592
# epoch 9, minibatch 883/883, validation cost 821896.750000 mse/pixel: 821896.750000 pnsr: -10.009519
#      epoch 9, minibatch 883/883, test cost of best model 800181.750000 perpixel mse 800181.687500 and test pnsr -10.174316
# epoch 10, minibatch 883/883, validation cost 470978.375000 mse/pixel: 470978.312500 pnsr: -7.518023
#      epoch 10, minibatch 883/883, test cost of best model 448965.343750 perpixel mse 448965.312500 and test pnsr -7.634381
# epoch 11, minibatch 883/883, validation cost 249566.156250 mse/pixel: 249566.125000 pnsr: -4.686879
#      epoch 11, minibatch 883/883, test cost of best model 231651.578125 perpixel mse 231651.562500 and test pnsr -4.704871
# epoch 12, minibatch 883/883, validation cost 132403.656250 mse/pixel: 132403.640625 pnsr: -1.892808
#      epoch 12, minibatch 883/883, test cost of best model 124175.406250 perpixel mse 124175.390625 and test pnsr -1.957676
# epoch 13, minibatch 883/883, validation cost 63995.246094 mse/pixel: 63995.242188 pnsr: 1.431269
#      epoch 13, minibatch 883/883, test cost of best model 61529.917969 perpixel mse 61529.917969 and test pnsr 1.245501
# epoch 14, minibatch 883/883, validation cost 33096.777344 mse/pixel: 33096.773438 pnsr: 4.394907
#      epoch 14, minibatch 883/883, test cost of best model 34053.265625 perpixel mse 34053.261719 and test pnsr 3.953789
# epoch 15, minibatch 883/883, validation cost 19606.169922 mse/pixel: 19606.169922 pnsr: 6.628005
#      epoch 15, minibatch 883/883, test cost of best model 22065.607422 perpixel mse 22065.605469 and test pnsr 5.952141
# epoch 16, minibatch 883/883, validation cost 13375.522461 mse/pixel: 13375.521484 pnsr: 8.276776
#      epoch 16, minibatch 883/883, test cost of best model 15550.202148 perpixel mse 15550.202148 and test pnsr 7.546787
# epoch 17, minibatch 883/883, validation cost 9967.963867 mse/pixel: 9967.963867 pnsr: 9.595355
#      epoch 17, minibatch 883/883, test cost of best model 11645.234375 perpixel mse 11645.234375 and test pnsr 8.822066
# epoch 18, minibatch 883/883, validation cost 7174.739746 mse/pixel: 7174.739258 pnsr: 11.172304
#      epoch 18, minibatch 883/883, test cost of best model 7673.868652 perpixel mse 7673.867676 and test pnsr 10.590178
# epoch 19, minibatch 883/883, validation cost 5440.545410 mse/pixel: 5440.545410 pnsr: 12.456927
#      epoch 19, minibatch 883/883, test cost of best model 5594.325684 perpixel mse 5594.324707 and test pnsr 11.886678
# epoch 20, minibatch 883/883, validation cost 4874.476074 mse/pixel: 4874.475586 pnsr: 12.750123
#      epoch 20, minibatch 883/883, test cost of best model 5112.390625 perpixel mse 5112.390625 and test pnsr 12.183155
# epoch 21, minibatch 883/883, validation cost 4278.919434 mse/pixel: 4278.918945 pnsr: 13.156504
#      epoch 21, minibatch 883/883, test cost of best model 4461.234375 perpixel mse 4461.233887 and test pnsr 12.586692
# epoch 22, minibatch 883/883, validation cost 3749.815918 mse/pixel: 3749.815918 pnsr: 13.554800
#      epoch 22, minibatch 883/883, test cost of best model 4119.528809 perpixel mse 4119.528809 and test pnsr 12.906777
# epoch 23, minibatch 883/883, validation cost 2968.583740 mse/pixel: 2968.583252 pnsr: 14.404992
#      epoch 23, minibatch 883/883, test cost of best model 3295.435303 perpixel mse 3295.435303 and test pnsr 13.886982
# epoch 24, minibatch 883/883, validation cost 2797.593994 mse/pixel: 2797.593994 pnsr: 14.615390
#      epoch 24, minibatch 883/883, test cost of best model 3308.501221 perpixel mse 3308.500977 and test pnsr 13.896257
# epoch 25, minibatch 883/883, validation cost 2649.143066 mse/pixel: 2649.142578 pnsr: 14.890061
#      epoch 25, minibatch 883/883, test cost of best model 3263.461670 perpixel mse 3263.461182 and test pnsr 14.016459
# epoch 26, minibatch 883/883, validation cost 2513.696777 mse/pixel: 2513.696777 pnsr: 15.089900
#      epoch 26, minibatch 883/883, test cost of best model 3220.892578 perpixel mse 3220.892334 and test pnsr 14.103861
# epoch 27, minibatch 883/883, validation cost 2479.364746 mse/pixel: 2479.364502 pnsr: 15.176601
#      epoch 27, minibatch 883/883, test cost of best model 3245.112549 perpixel mse 3245.112305 and test pnsr 14.124584
# epoch 28, minibatch 883/883, validation cost 2370.589111 mse/pixel: 2370.588623 pnsr: 15.360528
#      epoch 28, minibatch 883/883, test cost of best model 3140.510742 perpixel mse 3140.510498 and test pnsr 14.267756
# epoch 29, minibatch 883/883, validation cost 2251.022217 mse/pixel: 2251.021973 pnsr: 15.537341
#      epoch 29, minibatch 883/883, test cost of best model 2991.088379 perpixel mse 2991.087891 and test pnsr 14.426340
# epoch 30, minibatch 883/883, validation cost 2114.509521 mse/pixel: 2114.509521 pnsr: 15.768748
#      epoch 30, minibatch 883/883, test cost of best model 2830.258789 perpixel mse 2830.258545 and test pnsr 14.614589
# epoch 31, minibatch 883/883, validation cost 2011.708496 mse/pixel: 2011.708374 pnsr: 15.971670
#      epoch 31, minibatch 883/883, test cost of best model 2681.293213 perpixel mse 2681.292969 and test pnsr 14.823565
# epoch 32, minibatch 883/883, validation cost 2236.245361 mse/pixel: 2236.245117 pnsr: 15.539403
# epoch 33, minibatch 883/883, validation cost 2147.225098 mse/pixel: 2147.224854 pnsr: 15.699480
# epoch 34, minibatch 883/883, validation cost 1647.914429 mse/pixel: 1647.914307 pnsr: 16.747675
#      epoch 34, minibatch 883/883, test cost of best model 2269.074951 perpixel mse 2269.074951 and test pnsr 15.495936
# epoch 35, minibatch 883/883, validation cost 1310.932251 mse/pixel: 1310.932251 pnsr: 17.687973
#      epoch 35, minibatch 883/883, test cost of best model 1824.335449 perpixel mse 1824.335205 and test pnsr 16.423494
# epoch 36, minibatch 883/883, validation cost 1441.801392 mse/pixel: 1441.801392 pnsr: 17.321278
# epoch 37, minibatch 883/883, validation cost 1498.192383 mse/pixel: 1498.192261 pnsr: 17.164787
# epoch 38, minibatch 883/883, validation cost 1368.173340 mse/pixel: 1368.173340 pnsr: 17.535570
# epoch 39, minibatch 883/883, validation cost 1287.951416 mse/pixel: 1287.951294 pnsr: 17.806541
#      epoch 39, minibatch 883/883, test cost of best model 1741.701172 perpixel mse 1741.700928 and test pnsr 16.596886
# epoch 40, minibatch 883/883, validation cost 1180.390869 mse/pixel: 1180.390747 pnsr: 18.165142
#      epoch 40, minibatch 883/883, test cost of best model 1588.934326 perpixel mse 1588.934082 and test pnsr 16.982929
# epoch 41, minibatch 883/883, validation cost 1156.910156 mse/pixel: 1156.909912 pnsr: 18.307825
#      epoch 41, minibatch 883/883, test cost of best model 1538.698608 perpixel mse 1538.698608 and test pnsr 17.153528
# epoch 42, minibatch 883/883, validation cost 1152.075317 mse/pixel: 1152.075195 pnsr: 18.292374
#      epoch 42, minibatch 883/883, test cost of best model 1580.510254 perpixel mse 1580.510254 and test pnsr 17.067663
# epoch 43, minibatch 883/883, validation cost 1021.257324 mse/pixel: 1021.257324 pnsr: 18.819801
#      epoch 43, minibatch 883/883, test cost of best model 1370.468262 perpixel mse 1370.468140 and test pnsr 17.660288
# epoch 44, minibatch 883/883, validation cost 995.575500 mse/pixel: 995.575378 pnsr: 19.097454
#      epoch 44, minibatch 883/883, test cost of best model 1273.932861 perpixel mse 1273.932861 and test pnsr 17.973305
# epoch 45, minibatch 883/883, validation cost 1026.027832 mse/pixel: 1026.027832 pnsr: 19.151770
# epoch 46, minibatch 883/883, validation cost 915.127930 mse/pixel: 915.127930 pnsr: 19.837328
#      epoch 46, minibatch 883/883, test cost of best model 1056.862793 perpixel mse 1056.862671 and test pnsr 18.754696
# epoch 47, minibatch 883/883, validation cost 836.309204 mse/pixel: 836.309021 pnsr: 20.207876
#      epoch 47, minibatch 883/883, test cost of best model 975.567444 perpixel mse 975.567322 and test pnsr 19.107050
# epoch 48, minibatch 883/883, validation cost 723.259888 mse/pixel: 723.259766 pnsr: 20.490519
#      epoch 48, minibatch 883/883, test cost of best model 913.803955 perpixel mse 913.803894 and test pnsr 19.366085
# epoch 49, minibatch 883/883, validation cost 653.440857 mse/pixel: 653.440796 pnsr: 21.101791
#      epoch 49, minibatch 883/883, test cost of best model 793.951111 perpixel mse 793.951111 and test pnsr 20.001455
# epoch 50, minibatch 883/883, validation cost 458.395721 mse/pixel: 458.395721 pnsr: 22.394758
#      epoch 50, minibatch 883/883, test cost of best model 581.370972 perpixel mse 581.370972 and test pnsr 21.357134
# Optimization complete.
# Best validation pnsr of 458.395721 obtained at iteration 44150, with test cost 581.370972 perpixel mse 581.370972 test pnsr 21.357134
# The training process for function train_FSRCNN ran for 48.88m
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')

# %% [markdown]
# More Epochs

# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image
import FSRCNN_Theano3

data_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')

upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))


shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 25
n_epochs = 125
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano3.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv_100epochs')
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch_25_modelfull_SKIP_BasicDeconv-100epochs')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIPBasicDeconv_100epochs', place=True)
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv_100epochs',place=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/ubuntu/Data/Training_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Training_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Validation_Subsamples_RGB_4_gt
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4
# loading from npz
# /home/ubuntu/Data/Test_Subsamples_RGB_4_gt
# loading from npz
# (22092, 3, 8, 8)
# (22092, 3, 33, 33)
# (2488, 3, 8, 8)
# (14851, 3, 8, 8)
#
#
#  ****************************** lr = 0.0005******************************************
# theano optimizer: fast_compile
# ('batch size', 25)
# lovely....
#
# filter_shape...: (56, 3, 5, 5)
# image_shape...: (25, 3, 8, 8)
# input shape....: Shape.0
# conv1 done....
# lovely....
#
# filter_shape...: (12, 56, 3, 3)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (12, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# lovely....
#
# filter_shape...: (56, 12, 3, 3)
# image_shape...: (25, 12, 8, 8)
# input shape....: Shape.0
# decon layer....
#
# filter_shape...: (3, 56, 9, 9)
# image_shape...: (25, 56, 8, 8)
# input shape....: Shape.0
# Shape.0
# ('output len...', 16)
# epoch 1, minibatch 883/883, validation cost 35288484.000000 mse/pixel: 35288480.000000 pnsr: -26.629951
#      epoch 1, minibatch 883/883, test cost of best model 35346340.000000 perpixel mse 35346340.000000 and test pnsr -26.536722
# epoch 2, minibatch 883/883, validation cost 15816440.000000 mse/pixel: 15816439.000000 pnsr: -23.194208
#      epoch 2, minibatch 883/883, test cost of best model 16680595.000000 perpixel mse 16680593.000000 and test pnsr -23.333838
# epoch 3, minibatch 883/883, validation cost 9418434.000000 mse/pixel: 9418433.000000 pnsr: -20.875008
#      epoch 3, minibatch 883/883, test cost of best model 8702562.000000 perpixel mse 8702562.000000 and test pnsr -20.572994
# epoch 4, minibatch 883/883, validation cost 5329369.000000 mse/pixel: 5329369.000000 pnsr: -18.426474
#      epoch 4, minibatch 883/883, test cost of best model 5026100.000000 perpixel mse 5026099.500000 and test pnsr -18.169231
# epoch 5, minibatch 883/883, validation cost 3126253.250000 mse/pixel: 3126253.000000 pnsr: -16.141090
#      epoch 5, minibatch 883/883, test cost of best model 3230935.000000 perpixel mse 3230934.750000 and test pnsr -16.209572
# epoch 6, minibatch 883/883, validation cost 1976842.375000 mse/pixel: 1976842.125000 pnsr: -14.171592
#      epoch 6, minibatch 883/883, test cost of best model 2245495.500000 perpixel mse 2245495.500000 and test pnsr -14.527564
# epoch 7, minibatch 883/883, validation cost 1056773.625000 mse/pixel: 1056773.500000 pnsr: -11.425819
#      epoch 7, minibatch 883/883, test cost of best model 1141985.500000 perpixel mse 1141985.500000 and test pnsr -11.653215
# epoch 8, minibatch 883/883, validation cost 574257.250000 mse/pixel: 574257.187500 pnsr: -8.739722
#      epoch 8, minibatch 883/883, test cost of best model 596393.375000 perpixel mse 596393.375000 and test pnsr -8.833127
# epoch 9, minibatch 883/883, validation cost 314522.531250 mse/pixel: 314522.500000 pnsr: -6.082922
#      epoch 9, minibatch 883/883, test cost of best model 314688.093750 perpixel mse 314688.062500 and test pnsr -5.997142
# epoch 10, minibatch 883/883, validation cost 149720.906250 mse/pixel: 149720.890625 pnsr: -2.792704
#      epoch 10, minibatch 883/883, test cost of best model 151048.250000 perpixel mse 151048.250000 and test pnsr -2.672876
# epoch 11, minibatch 883/883, validation cost 53887.761719 mse/pixel: 53887.757812 pnsr: 1.542207
#      epoch 11, minibatch 883/883, test cost of best model 60097.574219 perpixel mse 60097.570312 and test pnsr 1.327719
# epoch 12, minibatch 883/883, validation cost 24568.183594 mse/pixel: 24568.183594 pnsr: 4.905296
#      epoch 12, minibatch 883/883, test cost of best model 27430.888672 perpixel mse 27430.888672 and test pnsr 4.628355
# epoch 13, minibatch 883/883, validation cost 20067.199219 mse/pixel: 20067.197266 pnsr: 5.823010
#      epoch 13, minibatch 883/883, test cost of best model 21780.265625 perpixel mse 21780.261719 and test pnsr 5.542228
# epoch 14, minibatch 883/883, validation cost 18517.201172 mse/pixel: 18517.201172 pnsr: 6.302715
#      epoch 14, minibatch 883/883, test cost of best model 19034.755859 perpixel mse 19034.755859 and test pnsr 6.108286
# epoch 15, minibatch 883/883, validation cost 15816.981445 mse/pixel: 15816.981445 pnsr: 7.006515
#      epoch 15, minibatch 883/883, test cost of best model 16102.629883 perpixel mse 16102.627930 and test pnsr 6.769085
# epoch 16, minibatch 883/883, validation cost 12375.343750 mse/pixel: 12375.343750 pnsr: 8.054118
#      epoch 16, minibatch 883/883, test cost of best model 13266.791016 perpixel mse 13266.791016 and test pnsr 7.668245
# epoch 17, minibatch 883/883, validation cost 8641.169922 mse/pixel: 8641.169922 pnsr: 9.608913
#      epoch 17, minibatch 883/883, test cost of best model 9462.039062 perpixel mse 9462.038086 and test pnsr 9.164416
# epoch 18, minibatch 883/883, validation cost 7490.986328 mse/pixel: 7490.986328 pnsr: 10.295844
#      epoch 18, minibatch 883/883, test cost of best model 8134.550293 perpixel mse 8134.550293 and test pnsr 9.835142
# epoch 19, minibatch 883/883, validation cost 7144.703125 mse/pixel: 7144.702637 pnsr: 10.523860
#      epoch 19, minibatch 883/883, test cost of best model 7827.452148 perpixel mse 7827.451172 and test pnsr 10.006321
# epoch 20, minibatch 883/883, validation cost 6967.328125 mse/pixel: 6967.328125 pnsr: 10.627900
#      epoch 20, minibatch 883/883, test cost of best model 7725.861816 perpixel mse 7725.861328 and test pnsr 10.053181
# epoch 21, minibatch 883/883, validation cost 6706.706543 mse/pixel: 6706.706543 pnsr: 10.800203
#      epoch 21, minibatch 883/883, test cost of best model 7494.990723 perpixel mse 7494.989746 and test pnsr 10.184869
# epoch 22, minibatch 883/883, validation cost 6352.642578 mse/pixel: 6352.642578 pnsr: 11.057895
#      epoch 22, minibatch 883/883, test cost of best model 7160.495117 perpixel mse 7160.495117 and test pnsr 10.396570
# epoch 23, minibatch 883/883, validation cost 5981.796875 mse/pixel: 5981.795898 pnsr: 11.336313
#      epoch 23, minibatch 883/883, test cost of best model 6808.556641 perpixel mse 6808.556641 and test pnsr 10.650014
# epoch 24, minibatch 883/883, validation cost 5024.903320 mse/pixel: 5024.902344 pnsr: 11.815145
#      epoch 24, minibatch 883/883, test cost of best model 6042.763672 perpixel mse 6042.763184 and test pnsr 11.348774
# epoch 25, minibatch 883/883, validation cost 4488.565430 mse/pixel: 4488.565430 pnsr: 11.989408
#      epoch 25, minibatch 883/883, test cost of best model 5563.336914 perpixel mse 5563.335938 and test pnsr 11.832172
# epoch 26, minibatch 883/883, validation cost 4072.364014 mse/pixel: 4072.364014 pnsr: 12.316789
#      epoch 26, minibatch 883/883, test cost of best model 5120.137207 perpixel mse 5120.136230 and test pnsr 12.195784
# epoch 27, minibatch 883/883, validation cost 3879.999023 mse/pixel: 3879.999023 pnsr: 12.503453
#      epoch 27, minibatch 883/883, test cost of best model 4909.250977 perpixel mse 4909.250977 and test pnsr 12.365503
# epoch 28, minibatch 883/883, validation cost 3762.791992 mse/pixel: 3762.791992 pnsr: 12.631056
#      epoch 28, minibatch 883/883, test cost of best model 4784.972168 perpixel mse 4784.972168 and test pnsr 12.464515
# epoch 29, minibatch 883/883, validation cost 3691.202393 mse/pixel: 3691.202393 pnsr: 12.708754
#      epoch 29, minibatch 883/883, test cost of best model 4711.318359 perpixel mse 4711.318359 and test pnsr 12.525590
# epoch 30, minibatch 883/883, validation cost 3707.119385 mse/pixel: 3707.119385 pnsr: 12.695219
# epoch 31, minibatch 883/883, validation cost 3708.136475 mse/pixel: 3708.135986 pnsr: 12.684751
# epoch 32, minibatch 883/883, validation cost 3774.811523 mse/pixel: 3774.811523 pnsr: 12.610116
# epoch 33, minibatch 883/883, validation cost 3733.832275 mse/pixel: 3733.832031 pnsr: 12.655839
# epoch 34, minibatch 883/883, validation cost 3687.761963 mse/pixel: 3687.761963 pnsr: 12.710260
#      epoch 34, minibatch 883/883, test cost of best model 5253.593750 perpixel mse 5253.593262 and test pnsr 12.338468
# epoch 35, minibatch 883/883, validation cost 3613.639893 mse/pixel: 3613.639160 pnsr: 12.800313
#      epoch 35, minibatch 883/883, test cost of best model 5211.397461 perpixel mse 5211.397461 and test pnsr 12.424513
# epoch 36, minibatch 883/883, validation cost 3553.380371 mse/pixel: 3553.380127 pnsr: 12.875393
#      epoch 36, minibatch 883/883, test cost of best model 5258.262695 perpixel mse 5258.261719 and test pnsr 12.468093
# epoch 37, minibatch 883/883, validation cost 3453.670410 mse/pixel: 3453.670166 pnsr: 13.001936
#      epoch 37, minibatch 883/883, test cost of best model 5006.729980 perpixel mse 5006.729980 and test pnsr 12.615346
# epoch 38, minibatch 883/883, validation cost 3413.456055 mse/pixel: 3413.456055 pnsr: 13.053050
#      epoch 38, minibatch 883/883, test cost of best model 4318.843262 perpixel mse 4318.843262 and test pnsr 12.686933
# epoch 39, minibatch 883/883, validation cost 3272.508301 mse/pixel: 3272.507812 pnsr: 13.233227
#      epoch 39, minibatch 883/883, test cost of best model 4475.438477 perpixel mse 4475.438477 and test pnsr 12.876487
# epoch 40, minibatch 883/883, validation cost 3359.664062 mse/pixel: 3359.663574 pnsr: 13.124288
# epoch 41, minibatch 883/883, validation cost 3282.502930 mse/pixel: 3282.501953 pnsr: 13.218724
# epoch 42, minibatch 883/883, validation cost 3204.598389 mse/pixel: 3204.597900 pnsr: 13.311204
#      epoch 42, minibatch 883/883, test cost of best model 4644.369629 perpixel mse 4644.369629 and test pnsr 12.810167
# epoch 43, minibatch 883/883, validation cost 3218.385010 mse/pixel: 3218.384521 pnsr: 13.315906
# epoch 44, minibatch 883/883, validation cost 3058.258301 mse/pixel: 3058.258301 pnsr: 13.509072
#      epoch 44, minibatch 883/883, test cost of best model 4371.563965 perpixel mse 4371.563965 and test pnsr 13.003775
# epoch 45, minibatch 883/883, validation cost 2980.196045 mse/pixel: 2980.195801 pnsr: 13.602545
#      epoch 45, minibatch 883/883, test cost of best model 4179.300293 perpixel mse 4179.300293 and test pnsr 13.084988
# epoch 46, minibatch 883/883, validation cost 3014.453613 mse/pixel: 3014.453369 pnsr: 13.561250
# epoch 47, minibatch 883/883, validation cost 2832.454346 mse/pixel: 2832.453613 pnsr: 13.803639
#      epoch 47, minibatch 883/883, test cost of best model 3927.026123 perpixel mse 3927.025635 and test pnsr 13.281924
# epoch 48, minibatch 883/883, validation cost 2776.148926 mse/pixel: 2776.148438 pnsr: 13.887590
#      epoch 48, minibatch 883/883, test cost of best model 3739.002197 perpixel mse 3739.001709 and test pnsr 13.425831
# epoch 49, minibatch 883/883, validation cost 2824.515381 mse/pixel: 2824.515137 pnsr: 13.812500
# epoch 50, minibatch 883/883, validation cost 2657.361328 mse/pixel: 2657.361084 pnsr: 14.050790
#      epoch 50, minibatch 883/883, test cost of best model 3589.375488 perpixel mse 3589.374512 and test pnsr 13.585883
# epoch 51, minibatch 883/883, validation cost 2646.741699 mse/pixel: 2646.741699 pnsr: 14.067062
#      epoch 51, minibatch 883/883, test cost of best model 3504.064453 perpixel mse 3504.064209 and test pnsr 13.605219
# epoch 52, minibatch 883/883, validation cost 2644.590820 mse/pixel: 2644.590576 pnsr: 14.076054
#      epoch 52, minibatch 883/883, test cost of best model 3438.114990 perpixel mse 3438.114746 and test pnsr 13.649092
# epoch 53, minibatch 883/883, validation cost 2524.730225 mse/pixel: 2524.729980 pnsr: 14.249381
#      epoch 53, minibatch 883/883, test cost of best model 3357.160400 perpixel mse 3357.160400 and test pnsr 13.784554
# epoch 54, minibatch 883/883, validation cost 2499.864014 mse/pixel: 2499.863525 pnsr: 14.288388
#      epoch 54, minibatch 883/883, test cost of best model 3266.561768 perpixel mse 3266.561768 and test pnsr 13.849103
# epoch 55, minibatch 883/883, validation cost 2536.498047 mse/pixel: 2536.497559 pnsr: 14.231586
# epoch 56, minibatch 883/883, validation cost 2620.965576 mse/pixel: 2620.965332 pnsr: 14.114789
# epoch 57, minibatch 883/883, validation cost 2455.806641 mse/pixel: 2455.806396 pnsr: 14.372639
#      epoch 57, minibatch 883/883, test cost of best model 3151.297607 perpixel mse 3151.297607 and test pnsr 13.954628
# epoch 58, minibatch 883/883, validation cost 2629.931396 mse/pixel: 2629.931396 pnsr: 14.106690
# epoch 59, minibatch 883/883, validation cost 2433.971924 mse/pixel: 2433.971924 pnsr: 14.399202
#      epoch 59, minibatch 883/883, test cost of best model 3104.323975 perpixel mse 3104.323975 and test pnsr 13.999846
# epoch 60, minibatch 883/883, validation cost 2694.850098 mse/pixel: 2694.850098 pnsr: 14.004302
# epoch 61, minibatch 883/883, validation cost 2405.296143 mse/pixel: 2405.296143 pnsr: 14.450274
#      epoch 61, minibatch 883/883, test cost of best model 3003.047119 perpixel mse 3003.046631 and test pnsr 14.080080
# epoch 62, minibatch 883/883, validation cost 2382.166016 mse/pixel: 2382.165771 pnsr: 14.485931
#      epoch 62, minibatch 883/883, test cost of best model 2961.718262 perpixel mse 2961.717773 and test pnsr 14.114195
# epoch 63, minibatch 883/883, validation cost 2656.143555 mse/pixel: 2656.143555 pnsr: 14.030950
# epoch 64, minibatch 883/883, validation cost 2624.320801 mse/pixel: 2624.320557 pnsr: 14.102789
# epoch 65, minibatch 883/883, validation cost 2380.078125 mse/pixel: 2380.078125 pnsr: 14.498273
#      epoch 65, minibatch 883/883, test cost of best model 2945.290039 perpixel mse 2945.289795 and test pnsr 14.153600
# epoch 66, minibatch 883/883, validation cost 2368.046143 mse/pixel: 2368.045654 pnsr: 14.502479
#      epoch 66, minibatch 883/883, test cost of best model 2924.508789 perpixel mse 2924.508301 and test pnsr 14.151594
# epoch 67, minibatch 883/883, validation cost 2464.824463 mse/pixel: 2464.824219 pnsr: 14.355247
# epoch 68, minibatch 883/883, validation cost 2418.186035 mse/pixel: 2418.185791 pnsr: 14.442011
# epoch 69, minibatch 883/883, validation cost 2320.874756 mse/pixel: 2320.874512 pnsr: 14.595548
#      epoch 69, minibatch 883/883, test cost of best model 2866.169678 perpixel mse 2866.169189 and test pnsr 14.261658
# epoch 70, minibatch 883/883, validation cost 2418.334961 mse/pixel: 2418.334961 pnsr: 14.422758
# epoch 71, minibatch 883/883, validation cost 2335.662842 mse/pixel: 2335.662842 pnsr: 14.566965
# epoch 72, minibatch 883/883, validation cost 2446.317139 mse/pixel: 2446.317139 pnsr: 14.379709
# epoch 73, minibatch 883/883, validation cost 2299.747314 mse/pixel: 2299.747070 pnsr: 14.648592
#      epoch 73, minibatch 883/883, test cost of best model 2877.320801 perpixel mse 2877.320801 and test pnsr 14.233106
# epoch 74, minibatch 883/883, validation cost 2282.543457 mse/pixel: 2282.543213 pnsr: 14.664108
#      epoch 74, minibatch 883/883, test cost of best model 2838.424316 perpixel mse 2838.424072 and test pnsr 14.260960
# epoch 75, minibatch 883/883, validation cost 2294.895752 mse/pixel: 2294.895752 pnsr: 14.639006
# epoch 76, minibatch 883/883, validation cost 2340.334717 mse/pixel: 2340.334473 pnsr: 14.565640
# epoch 77, minibatch 883/883, validation cost 2267.246582 mse/pixel: 2267.246338 pnsr: 14.700237
#      epoch 77, minibatch 883/883, test cost of best model 2789.495117 perpixel mse 2789.494873 and test pnsr 14.326955
# epoch 78, minibatch 883/883, validation cost 2254.589355 mse/pixel: 2254.589111 pnsr: 14.723312
#      epoch 78, minibatch 883/883, test cost of best model 2748.822510 perpixel mse 2748.822266 and test pnsr 14.379524
# epoch 79, minibatch 883/883, validation cost 2268.756836 mse/pixel: 2268.756836 pnsr: 14.686192
# epoch 80, minibatch 883/883, validation cost 2254.739990 mse/pixel: 2254.739502 pnsr: 14.728958
# epoch 81, minibatch 883/883, validation cost 2202.545410 mse/pixel: 2202.545166 pnsr: 14.810422
#      epoch 81, minibatch 883/883, test cost of best model 2654.234863 perpixel mse 2654.234619 and test pnsr 14.486069
# epoch 82, minibatch 883/883, validation cost 2454.089111 mse/pixel: 2454.089111 pnsr: 14.383487
# epoch 83, minibatch 883/883, validation cost 2308.123779 mse/pixel: 2308.123535 pnsr: 14.586119
# epoch 84, minibatch 883/883, validation cost 2191.056885 mse/pixel: 2191.056885 pnsr: 14.799910
#      epoch 84, minibatch 883/883, test cost of best model 2576.421387 perpixel mse 2576.420898 and test pnsr 14.566398
# epoch 85, minibatch 883/883, validation cost 2016.340942 mse/pixel: 2016.340942 pnsr: 15.162706
#      epoch 85, minibatch 883/883, test cost of best model 2291.814453 perpixel mse 2291.814209 and test pnsr 15.086819
# epoch 86, minibatch 883/883, validation cost 2080.544434 mse/pixel: 2080.544189 pnsr: 15.046981
# epoch 87, minibatch 883/883, validation cost 1872.806396 mse/pixel: 1872.806152 pnsr: 15.488454
#      epoch 87, minibatch 883/883, test cost of best model 2091.399902 perpixel mse 2091.399902 and test pnsr 15.439796
# epoch 88, minibatch 883/883, validation cost 1901.982910 mse/pixel: 1901.982910 pnsr: 15.427119
# epoch 89, minibatch 883/883, validation cost 1996.250122 mse/pixel: 1996.250000 pnsr: 15.265326
# epoch 90, minibatch 883/883, validation cost 1895.658569 mse/pixel: 1895.658325 pnsr: 15.449283
# epoch 91, minibatch 883/883, validation cost 1864.204346 mse/pixel: 1864.204102 pnsr: 15.521480
#      epoch 91, minibatch 883/883, test cost of best model 2138.803955 perpixel mse 2138.803955 and test pnsr 15.315361
# epoch 92, minibatch 883/883, validation cost 1954.596436 mse/pixel: 1954.596069 pnsr: 15.353280
# epoch 93, minibatch 883/883, validation cost 1841.040771 mse/pixel: 1841.040527 pnsr: 15.592383
#      epoch 93, minibatch 883/883, test cost of best model 1991.901245 perpixel mse 1991.901245 and test pnsr 15.651733
# epoch 94, minibatch 883/883, validation cost 1821.900757 mse/pixel: 1821.900757 pnsr: 15.631633
#      epoch 94, minibatch 883/883, test cost of best model 1927.009277 perpixel mse 1927.009033 and test pnsr 15.784005
# epoch 95, minibatch 883/883, validation cost 1846.942749 mse/pixel: 1846.942505 pnsr: 15.546640
# epoch 96, minibatch 883/883, validation cost 1880.360962 mse/pixel: 1880.360596 pnsr: 15.503153
# epoch 97, minibatch 883/883, validation cost 1795.452148 mse/pixel: 1795.452148 pnsr: 15.672262
#      epoch 97, minibatch 883/883, test cost of best model 1871.904663 perpixel mse 1871.904419 and test pnsr 15.905905
# epoch 98, minibatch 883/883, validation cost 1997.250000 mse/pixel: 1997.249878 pnsr: 15.324096
# epoch 99, minibatch 883/883, validation cost 1815.251221 mse/pixel: 1815.251099 pnsr: 15.638608
# epoch 100, minibatch 883/883, validation cost 1660.222534 mse/pixel: 1660.222534 pnsr: 16.047186
#      epoch 100, minibatch 883/883, test cost of best model 1988.752319 perpixel mse 1988.752319 and test pnsr 15.797275
# epoch 101, minibatch 883/883, validation cost 1526.668701 mse/pixel: 1526.668701 pnsr: 16.422400
#      epoch 101, minibatch 883/883, test cost of best model 1830.312744 perpixel mse 1830.312744 and test pnsr 16.145613
# epoch 102, minibatch 883/883, validation cost 1478.854980 mse/pixel: 1478.854858 pnsr: 16.552326
#      epoch 102, minibatch 883/883, test cost of best model 1810.151733 perpixel mse 1810.151733 and test pnsr 16.182756
# epoch 103, minibatch 883/883, validation cost 1554.108765 mse/pixel: 1554.108765 pnsr: 16.422832
# epoch 104, minibatch 883/883, validation cost 1453.486084 mse/pixel: 1453.486084 pnsr: 16.612606
#      epoch 104, minibatch 883/883, test cost of best model 1821.296265 perpixel mse 1821.296143 and test pnsr 16.124102
# epoch 105, minibatch 883/883, validation cost 1417.181763 mse/pixel: 1417.181763 pnsr: 16.723492
#      epoch 105, minibatch 883/883, test cost of best model 1729.676758 perpixel mse 1729.676758 and test pnsr 16.355148
# epoch 106, minibatch 883/883, validation cost 1396.003418 mse/pixel: 1396.003296 pnsr: 16.789940
#      epoch 106, minibatch 883/883, test cost of best model 1705.819458 perpixel mse 1705.819214 and test pnsr 16.380150
# epoch 107, minibatch 883/883, validation cost 1378.288818 mse/pixel: 1378.288696 pnsr: 16.906849
#      epoch 107, minibatch 883/883, test cost of best model 1576.483398 perpixel mse 1576.483398 and test pnsr 16.660299
# epoch 108, minibatch 883/883, validation cost 1352.246704 mse/pixel: 1352.246582 pnsr: 16.930122
#      epoch 108, minibatch 883/883, test cost of best model 1605.835327 perpixel mse 1605.835205 and test pnsr 16.598139
# epoch 109, minibatch 883/883, validation cost 1316.583374 mse/pixel: 1316.583252 pnsr: 17.072596
#      epoch 109, minibatch 883/883, test cost of best model 1515.642700 perpixel mse 1515.642700 and test pnsr 16.810867
# epoch 110, minibatch 883/883, validation cost 1274.256104 mse/pixel: 1274.256104 pnsr: 17.204010
#      epoch 110, minibatch 883/883, test cost of best model 1586.964355 perpixel mse 1586.964233 and test pnsr 16.715666
# epoch 111, minibatch 883/883, validation cost 1226.013672 mse/pixel: 1226.013672 pnsr: 17.382986
#      epoch 111, minibatch 883/883, test cost of best model 1469.442505 perpixel mse 1469.442505 and test pnsr 16.951578
# epoch 112, minibatch 883/883, validation cost 1200.088501 mse/pixel: 1200.088379 pnsr: 17.544443
#      epoch 112, minibatch 883/883, test cost of best model 1337.565186 perpixel mse 1337.565063 and test pnsr 17.356853
# epoch 113, minibatch 883/883, validation cost 1164.548706 mse/pixel: 1164.548584 pnsr: 17.643307
#      epoch 113, minibatch 883/883, test cost of best model 1363.086914 perpixel mse 1363.086792 and test pnsr 17.263868
# epoch 114, minibatch 883/883, validation cost 1139.487183 mse/pixel: 1139.487061 pnsr: 17.749521
#      epoch 114, minibatch 883/883, test cost of best model 1345.132812 perpixel mse 1345.132812 and test pnsr 17.319803
# epoch 115, minibatch 883/883, validation cost 1187.443359 mse/pixel: 1187.443237 pnsr: 17.617922
# epoch 116, minibatch 883/883, validation cost 1093.543823 mse/pixel: 1093.543823 pnsr: 17.931215
#      epoch 116, minibatch 883/883, test cost of best model 1323.241455 perpixel mse 1323.241333 and test pnsr 17.428337
# epoch 117, minibatch 883/883, validation cost 1144.581543 mse/pixel: 1144.581543 pnsr: 17.795998
# epoch 118, minibatch 883/883, validation cost 1094.984985 mse/pixel: 1094.984985 pnsr: 17.923180
# epoch 119, minibatch 883/883, validation cost 1095.947876 mse/pixel: 1095.947876 pnsr: 17.922312
# epoch 120, minibatch 883/883, validation cost 1082.721924 mse/pixel: 1082.721802 pnsr: 17.974119
#      epoch 120, minibatch 883/883, test cost of best model 1262.412354 perpixel mse 1262.412231 and test pnsr 17.633514
# epoch 121, minibatch 883/883, validation cost 1078.560669 mse/pixel: 1078.560669 pnsr: 17.955215
#      epoch 121, minibatch 883/883, test cost of best model 1307.976807 perpixel mse 1307.976685 and test pnsr 17.447039
# epoch 122, minibatch 883/883, validation cost 1039.898560 mse/pixel: 1039.898438 pnsr: 18.131086
#      epoch 122, minibatch 883/883, test cost of best model 1233.359009 perpixel mse 1233.359009 and test pnsr 17.707886
# epoch 123, minibatch 883/883, validation cost 1086.007324 mse/pixel: 1086.007202 pnsr: 17.960510
# epoch 124, minibatch 883/883, validation cost 1026.668823 mse/pixel: 1026.668701 pnsr: 18.165895
#      epoch 124, minibatch 883/883, test cost of best model 1267.725830 perpixel mse 1267.725708 and test pnsr 17.629314
# epoch 125, minibatch 883/883, validation cost 1009.031189 mse/pixel: 1009.031189 pnsr: 18.265295
#      epoch 125, minibatch 883/883, test cost of best model 1178.927979 perpixel mse 1178.927979 and test pnsr 17.911949
# Optimization complete.
# Best validation pnsr of 1009.031189 obtained at iteration 110375, with test cost 1178.927979 perpixel mse 1178.927979 test pnsr 17.911949
# The training process for function train_FSRCNN ran for 153.01m
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 288, '\n')
# (19, 19, '\n')
# (256, 256, '\n')
# (16, 16, '\n')
# (280, 280, '\n')
# (18, 18, '\n')
# (344, 228, '\n')
# (23, 14, '\n')
# (480, 500, '\n')
# (32, 34, '\n')
# (576, 720, '\n')
# (39, 50, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (361, 250, '\n')
# (24, 16, '\n')
# (276, 276, '\n')
# (18, 18, '\n')
# (362, 500, '\n')
# (24, 34, '\n')
# (288, 352, '\n')
# (19, 23, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (512, 768, '\n')
# (35, 53, '\n')
# (512, 512, '\n')
# (35, 35, '\n')
# (656, 529, '\n')
# (45, 36, '\n')
# (391, 586, '\n')
# (26, 40, '\n')

# %%
# %load_ext autoreload
# %autoreload 2
import theano
import theano.tensor as T
import numpy as np
import FSRCNN_Theano2
import os
import Fpreprocessing
from scipy import ndimage,misc
from PIL import Image
import FSRCNN_Theano3

data_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4','data_x')
data_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Training_Subsamples_RGB_4_gt','data_y')
valid_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4','data_x')
valid_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Validation_Subsamples_RGB_4_gt','data_y')
test_x = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4','data_x')
test_y = FSRCNN_Theano3.load_dataset('/home/ubuntu/Data/Test_Subsamples_RGB_4_gt','data_y')

upsampled_x = data_x #Fpreprocessing.upsample(data_x) #33,33,3 input images expected
up_val_x = valid_x #Fpreprocessing.upsample(valid_x) #33,33,3 input images expected
up_test_x = test_x #Fpreprocessing.upsample(test_x) #33,33,3 input images expected

#Reshape for training,valid,test

print upsampled_x.shape
print data_y.shape
print up_val_x.shape
print up_test_x.shape

upsampled_x = upsampled_x.reshape((22092,8*8*3))
data_y = data_y.reshape((22092,33*33*3))
up_val_x = up_val_x.reshape((2488,8*8*3))
valid_y = valid_y.reshape((2488,33*33*3))
up_test_x = up_test_x.reshape((14851,8*8*3))
test_y = test_y.reshape((14851,33*33*3))


shared_x = theano.shared(np.asarray(upsampled_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_y = theano.shared(np.asarray(data_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_x = theano.shared(np.asarray(up_val_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_val_y = theano.shared(np.asarray(valid_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_x = theano.shared(np.asarray(up_test_x,
                                       dtype=theano.config.floatX),
                         borrow=True)
shared_test_y = theano.shared(np.asarray(test_y,
                                       dtype=theano.config.floatX),
                         borrow=True)
batch_size = 25
n_epochs = 200
lrs = [.0005]
for lr in lrs:
    print "\n\n ****************************** lr = " + str(lr) +"******************************************"
    learning_rate = lr

    n_train_batches = upsampled_x.shape[0]/batch_size
    n_valid_batches = up_val_x.shape[0]/batch_size
    n_test_batches = up_test_x.shape[0]/batch_size



    val_model,test_model = FSRCNN_Theano3.train_FSRCNN(shared_x,shared_y,
                             shared_val_x,shared_val_y,
                             shared_test_x,shared_test_y,
                            n_train_batches, n_valid_batches, n_test_batches, 
                             n_epochs, batch_size,learning_rate,upsampling_factor=4)
reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv_100epochs')
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch_25_modelfull_SKIP_BasicDeconv-100epochs')

reconstructed_imgs = np.zeros(((n_valid_batches+1)*batch_size, 3, 16, 16))
for i in xrange(n_valid_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = val_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Validation_Subsamples_RGB_4',patch_dim=16,dataset='validate_lr=5e4_batch=25_modelfull_SKIPBasicDeconv_100epochs', place=True)
reconstructed_imgs = np.zeros((14851, 3, 16, 16))
for i in xrange(n_test_batches):
     cost,MSE_per_pixel,psnr,reconstucted_patches = test_model(i)
     reconstructed_imgs[i*batch_size:(i+1)*batch_size,:,:,:] = reconstucted_patches

FSRCNN_Theano3.rebuild_images(reconstructed_imgs,'/home/ubuntu/Data/Test_Subsamples_RGB_4',patch_dim=16,dataset='test_lr=5e4_batch=25_modelfull_SKIP_BasicDeconv_100epochs',place=True)
